# %%
pip install seaborn matplotlib
# Out:
# Requirement already satisfied: seaborn in /usr/local/lib/python3.10/dist-packages (0.13.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.7.1)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /usr/local/lib/python3.10/dist-packages (from seaborn) (1.25.2)
# Requirement already satisfied: pandas>=1.2 in /usr/local/lib/python3.10/dist-packages (from seaborn) (1.5.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.49.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.2->seaborn) (2023.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
import keras
import pandas as pd
import numpy as np
import itertools
import seaborn as sns
from sklearn import svm
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.metrics import f1_score
from sklearn.metrics import auc
from keras.models import Sequential
from tensorflow.keras import models, layers
from sklearn.metrics import confusion_matrix
from tensorflow.keras.applications import VGG16
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import roc_curve, roc_auc_score
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import average_precision_score
from tensorflow.keras.utils import plot_model
from tensorflow.keras.optimizers.schedules import ExponentialDecay
from keras. layers import Activation, Dropout, Flatten, Dense
from sklearn.model_selection import train_test_split, cross_val_score
from keras.layers import Conv1D, MaxPooling2D, MaxPooling1D, BatchNormalization
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
import warnings
warnings.filterwarnings('ignore')
def ignore_warn(*args, **kwargs):
  pass
  warnings.warn=ignore_warn

# %%
BATCH_SIZE = 32
IMAGE_SIZE = 300
CHANNELS=3
EPOCHS=98

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
dataset = tf.keras.preprocessing.image_dataset_from_directory(
    "/content/drive/MyDrive/Paddy Leaf Disease Detection/Final_Dataset(RLDD)",
    seed=123,
    shuffle=True,
    image_size=(IMAGE_SIZE,IMAGE_SIZE),
    batch_size=BATCH_SIZE
)
# Out:
# Found 1850 files belonging to 6 classes.

# %%
class_names = dataset.class_names
class_names
# Out:
# ['Bacterial_leaf_blight',
#  'Brown_spot',
#  'Healthy_leaf',
#  'Leaf_Blast',
#  'Other',
#  'Tungro']

# %%
for image_batch, labels_batch in dataset.take(1):
    print(image_batch.shape)
    print(labels_batch.numpy())
# Out:
# (32, 300, 300, 3)
# [5 4 0 3 2 2 1 3 2 5 0 4 4 1 4 4 3 2 2 4 3 5 2 3 1 1 2 2 1 2 4 2]

# %%
new_image_size = (256, 256)
resized_dataset = dataset.map(lambda x, y: (tf.image.resize(x, new_image_size), y))
for image_batch, labels_batch in resized_dataset.take(1):
    print(image_batch.shape)
# Out:
# (32, 256, 256, 3)

# %%
import random
# Assuming you have a list of colors corresponding to each class
class_colors = [f'#{random.randint(0, 0xFFFFFF):06x}' for _ in class_names]

class_counts = [0] * len(class_names)
for images_batch, labels_batch in resized_dataset:# resized_dataset
    for label in labels_batch:
        class_counts[label] += 1

plt.figure(figsize=(6, 6))
patches, texts, autotexts = plt.pie(class_counts,
                                   autopct='%1.1f%%', startangle=140, colors=class_colors)

plt.legend(patches, class_names, loc='center left', bbox_to_anchor=(1, 0.5))

plt.title("Class Label Distribution")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Create a list to store the count of each class label
class_counts = [0] * len(class_names)
for images_batch, labels_batch in resized_dataset:
    for label in labels_batch:
        class_counts[label] += 1

# Plotting the bar chart
plt.figure(figsize=(10, 6))
plt.bar(class_names, class_counts, color='skyblue')
plt.title("Class Label Distribution")
plt.xlabel("Class Labels")
plt.ylabel("Count")
plt.xticks(rotation=45, ha="right")
plt.show()

# %%
plt.figure(figsize=(10, 10))
for image_batch, label_batch in resized_dataset.take(1):
  for i in range(12):
    ax = plt.subplot(3,4,i+1)
    plt.imshow(image_batch[i].numpy().astype("uint8"))
    plt.title(class_names[label_batch[i]])
    plt.axis("off")
  #print(image_batch[0].shape)

# %%
train_size = 0.8
len(resized_dataset)*train_size
# Out:
# 46.400000000000006

# %%
train_ds= resized_dataset.take(46)
len(train_ds)
# Out:
# 46

# %%
test_ds = resized_dataset.skip(46)
len(test_ds)
# Out:
# 12

# %%
val_size = 0.1
len(resized_dataset)*val_size
# Out:
# 5.800000000000001

# %%
val_ds = test_ds.take(6)
len(val_ds)
# Out:
# 6

# %%
test_ds = test_ds.skip(6)
len(test_ds)
# Out:
# 6

# %%
def get_dataset_partitions_tf(ds, train_split=0.8, val_split=0.1, test_split=0.1, shuffle=True, shuffle_size=10000):
    assert (train_split + test_split + val_split) == 1
    ds_size = len(ds)
    if shuffle:
      ds = ds.shuffle(shuffle_size, seed=12)
      train_size = int(train_split * ds_size)
      val_size = int(val_split * ds_size)
      train_ds = ds.take(train_size)
      val_ds = ds.skip(train_size).take(val_size)
      test_ds = ds.skip(train_size).skip(val_size)
      return train_ds, val_ds, test_ds

# %%
train_ds, val_ds, test_ds = get_dataset_partitions_tf(resized_dataset)

# %%
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)
val_ds = val_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)
test_ds = test_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)

# %%
resize_and_rescale = tf.keras.Sequential([
  layers.experimental.preprocessing.Resizing(256, 256),
  layers.experimental.preprocessing.Rescaling(1./255),
])

# %%
data_augmentation = tf.keras.Sequential([
  layers.experimental.preprocessing.RandomFlip("horizontal_and_vertical",dtype=tf.float32),  # Explicitly set data type
    # ... other preprocessing layers
  layers.experimental.preprocessing.RandomRotation(0.2),
  layers.experimental.preprocessing.RandomZoom(0.1),
  layers.experimental.preprocessing.RandomContrast(0.2),
])

# %%
train_ds = train_ds.map(
    lambda x, y: (data_augmentation(x, training=True), y)
).prefetch(buffer_size=tf.data.AUTOTUNE)

# %%
VGG16_model = VGG16(weights='imagenet', include_top=False, input_shape=(256, 256, CHANNELS))
for layer in VGG16_model.layers:
    layer.trainable = False

VGG16_model = tf.keras.Sequential([
    layers.Input(shape=(256, 256, CHANNELS)),
    VGG16_model,
    layers.GlobalAveragePooling2D(),
    layers.Dense(6, activation='softmax')
])

VGG16_model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 4s 0us/step
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 8, 8, 512)         14714688
#
#  global_average_pooling2d (  (None, 512)               0
#  GlobalAveragePooling2D)
#
#  dense (Dense)               (None, 6)                 3078
#
# =================================================================
# Total params: 14717766 (56.14 MB)
# Trainable params: 3078 (12.02 KB)
# Non-trainable params: 14714688 (56.13 MB)
# _________________________________________________________________

# %%
plot_model(VGG16_model, to_file='resnet_lstm.png', show_shapes=True)

# %%
from tensorflow.keras.optimizers.schedules import ExponentialDecay
initial_learning_rate = 0.001
lr_schedule = ExponentialDecay(
    initial_learning_rate, decay_steps=1000, decay_rate=0.9, staircase=True
    )

# %%
VGG16_model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=lr_schedule),
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
    metrics=['accuracy']
)

# %%
history = VGG16_model.fit(
    train_ds,
    batch_size=BATCH_SIZE,
    validation_data=val_ds,
    verbose=1,
    epochs=EPOCHS,
)
# Out:
# Epoch 1/98
# 46/46 [==============================] - 450s 861ms/step - loss: 2.1432 - accuracy: 0.4147 - val_loss: 1.2639 - val_accuracy: 0.5562
# Epoch 2/98
# 46/46 [==============================] - 27s 583ms/step - loss: 0.9433 - accuracy: 0.6664 - val_loss: 0.8592 - val_accuracy: 0.6938
# Epoch 3/98
# 46/46 [==============================] - 27s 588ms/step - loss: 0.7146 - accuracy: 0.7531 - val_loss: 0.7096 - val_accuracy: 0.7563
# Epoch 4/98
# 46/46 [==============================] - 27s 577ms/step - loss: 0.5342 - accuracy: 0.8035 - val_loss: 0.5548 - val_accuracy: 0.7937
# Epoch 5/98
# 46/46 [==============================] - 27s 586ms/step - loss: 0.5213 - accuracy: 0.8165 - val_loss: 0.4496 - val_accuracy: 0.8500
# Epoch 6/98
# 46/46 [==============================] - 27s 585ms/step - loss: 0.4283 - accuracy: 0.8458 - val_loss: 0.3667 - val_accuracy: 0.8750
# Epoch 7/98
# 46/46 [==============================] - 27s 583ms/step - loss: 0.3826 - accuracy: 0.8629 - val_loss: 0.3271 - val_accuracy: 0.8813
# Epoch 8/98
# 46/46 [==============================] - 28s 603ms/step - loss: 0.3613 - accuracy: 0.8772 - val_loss: 0.3020 - val_accuracy: 0.9000
# Epoch 9/98
# 46/46 [==============================] - 27s 589ms/step - loss: 0.3238 - accuracy: 0.8834 - val_loss: 0.2884 - val_accuracy: 0.9062
# Epoch 10/98
# 46/46 [==============================] - 27s 583ms/step - loss: 0.3148 - accuracy: 0.8943 - val_loss: 0.2745 - val_accuracy: 0.9125
# Epoch 11/98
# 46/46 [==============================] - 27s 585ms/step - loss: 0.2728 - accuracy: 0.9113 - val_loss: 0.2788 - val_accuracy: 0.9250
# Epoch 12/98
# 46/46 [==============================] - 27s 587ms/step - loss: 0.2704 - accuracy: 0.9031 - val_loss: 0.2402 - val_accuracy: 0.9438
# Epoch 13/98
# 46/46 [==============================] - 27s 586ms/step - loss: 0.2448 - accuracy: 0.9209 - val_loss: 0.2601 - val_accuracy: 0.9250
# Epoch 14/98
# 46/46 [==============================] - 27s 578ms/step - loss: 0.2636 - accuracy: 0.9113 - val_loss: 0.2354 - val_accuracy: 0.9375
# Epoch 15/98
# 46/46 [==============================] - 26s 573ms/step - loss: 0.2409 - accuracy: 0.9141 - val_loss: 0.2392 - val_accuracy: 0.9312
# Epoch 16/98
# 46/46 [==============================] - 27s 584ms/step - loss: 0.2429 - accuracy: 0.9195 - val_loss: 0.2299 - val_accuracy: 0.9312
# Epoch 17/98
# 46/46 [==============================] - 27s 578ms/step - loss: 0.2283 - accuracy: 0.9209 - val_loss: 0.2298 - val_accuracy: 0.9375
# Epoch 18/98
# 46/46 [==============================] - 27s 588ms/step - loss: 0.2113 - accuracy: 0.9236 - val_loss: 0.2230 - val_accuracy: 0.9250
# Epoch 19/98
# 46/46 [==============================] - 27s 584ms/step - loss: 0.2303 - accuracy: 0.9195 - val_loss: 0.2417 - val_accuracy: 0.9000
# Epoch 20/98
# 46/46 [==============================] - 27s 583ms/step - loss: 0.2111 - accuracy: 0.9284 - val_loss: 0.2257 - val_accuracy: 0.9312
# Epoch 21/98
# 46/46 [==============================] - 27s 598ms/step - loss: 0.1944 - accuracy: 0.9325 - val_loss: 0.2451 - val_accuracy: 0.9125
# Epoch 22/98
# 46/46 [==============================] - 28s 609ms/step - loss: 0.2130 - accuracy: 0.9311 - val_loss: 0.2204 - val_accuracy: 0.9375
# Epoch 23/98
# 46/46 [==============================] - 27s 580ms/step - loss: 0.1943 - accuracy: 0.9325 - val_loss: 0.1953 - val_accuracy: 0.9438
# Epoch 24/98
# 46/46 [==============================] - 27s 581ms/step - loss: 0.1851 - accuracy: 0.9366 - val_loss: 0.2064 - val_accuracy: 0.9438
# Epoch 25/98
# 46/46 [==============================] - 27s 583ms/step - loss: 0.1783 - accuracy: 0.9413 - val_loss: 0.1920 - val_accuracy: 0.9563
# Epoch 26/98
# 46/46 [==============================] - 27s 594ms/step - loss: 0.1685 - accuracy: 0.9427 - val_loss: 0.2074 - val_accuracy: 0.9500
# Epoch 27/98
# 46/46 [==============================] - 26s 576ms/step - loss: 0.1920 - accuracy: 0.9366 - val_loss: 0.2028 - val_accuracy: 0.9438
# Epoch 28/98
# 46/46 [==============================] - 27s 589ms/step - loss: 0.1875 - accuracy: 0.9345 - val_loss: 0.1831 - val_accuracy: 0.9438
# Epoch 29/98
# 46/46 [==============================] - 27s 591ms/step - loss: 0.1795 - accuracy: 0.9366 - val_loss: 0.1962 - val_accuracy: 0.9438
# Epoch 30/98
# 46/46 [==============================] - 27s 581ms/step - loss: 0.1806 - accuracy: 0.9332 - val_loss: 0.1799 - val_accuracy: 0.9375
# Epoch 31/98
# 46/46 [==============================] - 27s 592ms/step - loss: 0.1795 - accuracy: 0.9468 - val_loss: 0.1823 - val_accuracy: 0.9438
# Epoch 32/98
# 46/46 [==============================] - 27s 592ms/step - loss: 0.1644 - accuracy: 0.9468 - val_loss: 0.1778 - val_accuracy: 0.9375
# Epoch 33/98
# 46/46 [==============================] - 27s 583ms/step - loss: 0.1655 - accuracy: 0.9475 - val_loss: 0.1760 - val_accuracy: 0.9375
# Epoch 34/98
# 46/46 [==============================] - 27s 575ms/step - loss: 0.1668 - accuracy: 0.9475 - val_loss: 0.1977 - val_accuracy: 0.9312
# Epoch 35/98
# 46/46 [==============================] - 27s 589ms/step - loss: 0.1544 - accuracy: 0.9502 - val_loss: 0.2208 - val_accuracy: 0.9375
# Epoch 36/98
# 46/46 [==============================] - 27s 586ms/step - loss: 0.1633 - accuracy: 0.9447 - val_loss: 0.1944 - val_accuracy: 0.9187
# Epoch 37/98
# 46/46 [==============================] - 27s 579ms/step - loss: 0.1512 - accuracy: 0.9461 - val_loss: 0.2039 - val_accuracy: 0.9438
# Epoch 38/98
# 46/46 [==============================] - 27s 578ms/step - loss: 0.1561 - accuracy: 0.9475 - val_loss: 0.1846 - val_accuracy: 0.9438
# Epoch 39/98
# 46/46 [==============================] - 27s 587ms/step - loss: 0.1476 - accuracy: 0.9495 - val_loss: 0.1938 - val_accuracy: 0.9187
# Epoch 40/98
# 46/46 [==============================] - 26s 573ms/step - loss: 0.1578 - accuracy: 0.9434 - val_loss: 0.1844 - val_accuracy: 0.9438
# Epoch 41/98
# 46/46 [==============================] - 27s 585ms/step - loss: 0.1393 - accuracy: 0.9557 - val_loss: 0.1957 - val_accuracy: 0.9250
# Epoch 42/98
# 46/46 [==============================] - 28s 599ms/step - loss: 0.1424 - accuracy: 0.9509 - val_loss: 0.2227 - val_accuracy: 0.8875
# Epoch 43/98
# 46/46 [==============================] - 27s 586ms/step - loss: 0.1536 - accuracy: 0.9434 - val_loss: 0.2453 - val_accuracy: 0.9062
# Epoch 44/98
# 46/46 [==============================] - 28s 598ms/step - loss: 0.1567 - accuracy: 0.9461 - val_loss: 0.1933 - val_accuracy: 0.9312
# Epoch 45/98
# 46/46 [==============================] - 28s 600ms/step - loss: 0.1375 - accuracy: 0.9536 - val_loss: 0.2015 - val_accuracy: 0.9250
# Epoch 46/98
# 46/46 [==============================] - 27s 592ms/step - loss: 0.1367 - accuracy: 0.9529 - val_loss: 0.2020 - val_accuracy: 0.9438
# Epoch 47/98
# 46/46 [==============================] - 27s 578ms/step - loss: 0.1439 - accuracy: 0.9420 - val_loss: 0.2118 - val_accuracy: 0.9062
# Epoch 48/98
# 46/46 [==============================] - 27s 590ms/step - loss: 0.1350 - accuracy: 0.9577 - val_loss: 0.1793 - val_accuracy: 0.9438
# Epoch 49/98
# 46/46 [==============================] - 27s 590ms/step - loss: 0.1449 - accuracy: 0.9475 - val_loss: 0.1822 - val_accuracy: 0.9375
# Epoch 50/98
# 46/46 [==============================] - 27s 580ms/step - loss: 0.1367 - accuracy: 0.9550 - val_loss: 0.1950 - val_accuracy: 0.9375
# Epoch 51/98
# 46/46 [==============================] - 27s 581ms/step - loss: 0.1297 - accuracy: 0.9550 - val_loss: 0.2045 - val_accuracy: 0.9312
# Epoch 52/98
# 46/46 [==============================] - 27s 588ms/step - loss: 0.1403 - accuracy: 0.9468 - val_loss: 0.1913 - val_accuracy: 0.9312
# Epoch 53/98
# 46/46 [==============================] - 27s 588ms/step - loss: 0.1280 - accuracy: 0.9529 - val_loss: 0.1990 - val_accuracy: 0.9250
# Epoch 54/98
# 46/46 [==============================] - 27s 581ms/step - loss: 0.1366 - accuracy: 0.9509 - val_loss: 0.1809 - val_accuracy: 0.9500
# Epoch 55/98
# 46/46 [==============================] - 27s 581ms/step - loss: 0.1301 - accuracy: 0.9543 - val_loss: 0.1808 - val_accuracy: 0.9312
# Epoch 56/98
# 46/46 [==============================] - 27s 579ms/step - loss: 0.1368 - accuracy: 0.9523 - val_loss: 0.1856 - val_accuracy: 0.9438
# Epoch 57/98
# 46/46 [==============================] - 27s 596ms/step - loss: 0.1348 - accuracy: 0.9550 - val_loss: 0.1787 - val_accuracy: 0.9312
# Epoch 58/98
# 46/46 [==============================] - 27s 588ms/step - loss: 0.1342 - accuracy: 0.9557 - val_loss: 0.1877 - val_accuracy: 0.9312
# Epoch 59/98
# 46/46 [==============================] - 27s 591ms/step - loss: 0.1311 - accuracy: 0.9550 - val_loss: 0.1878 - val_accuracy: 0.9250
# Epoch 60/98
# 46/46 [==============================] - 27s 593ms/step - loss: 0.1298 - accuracy: 0.9523 - val_loss: 0.1727 - val_accuracy: 0.9250
# Epoch 61/98
# 46/46 [==============================] - 28s 601ms/step - loss: 0.1266 - accuracy: 0.9611 - val_loss: 0.1788 - val_accuracy: 0.9312
# Epoch 62/98
# 46/46 [==============================] - 28s 602ms/step - loss: 0.1319 - accuracy: 0.9584 - val_loss: 0.1737 - val_accuracy: 0.9312
# Epoch 63/98
# 46/46 [==============================] - 27s 593ms/step - loss: 0.1236 - accuracy: 0.9570 - val_loss: 0.1707 - val_accuracy: 0.9250
# Epoch 64/98
# 46/46 [==============================] - 27s 593ms/step - loss: 0.1238 - accuracy: 0.9557 - val_loss: 0.1844 - val_accuracy: 0.9375
# Epoch 65/98
# 46/46 [==============================] - 27s 586ms/step - loss: 0.1329 - accuracy: 0.9516 - val_loss: 0.1682 - val_accuracy: 0.9312
# Epoch 66/98
# 46/46 [==============================] - 27s 589ms/step - loss: 0.1074 - accuracy: 0.9679 - val_loss: 0.1672 - val_accuracy: 0.9375
# Epoch 67/98
# 46/46 [==============================] - 27s 583ms/step - loss: 0.1171 - accuracy: 0.9625 - val_loss: 0.1709 - val_accuracy: 0.9375
# Epoch 68/98
# 46/46 [==============================] - 27s 582ms/step - loss: 0.1006 - accuracy: 0.9686 - val_loss: 0.1730 - val_accuracy: 0.9438
# Epoch 69/98
# 46/46 [==============================] - 27s 580ms/step - loss: 0.1438 - accuracy: 0.9461 - val_loss: 0.1656 - val_accuracy: 0.9375
# Epoch 70/98
# 46/46 [==============================] - 28s 606ms/step - loss: 0.1215 - accuracy: 0.9563 - val_loss: 0.1666 - val_accuracy: 0.9312
# Epoch 71/98
# 46/46 [==============================] - 27s 583ms/step - loss: 0.1116 - accuracy: 0.9645 - val_loss: 0.1692 - val_accuracy: 0.9375
# Epoch 72/98
# 46/46 [==============================] - 27s 589ms/step - loss: 0.1048 - accuracy: 0.9659 - val_loss: 0.1911 - val_accuracy: 0.9375
# Epoch 73/98
# 46/46 [==============================] - 27s 594ms/step - loss: 0.1065 - accuracy: 0.9604 - val_loss: 0.1897 - val_accuracy: 0.9312
# Epoch 74/98
# 46/46 [==============================] - 27s 584ms/step - loss: 0.1178 - accuracy: 0.9557 - val_loss: 0.1793 - val_accuracy: 0.9312
# Epoch 75/98
# 46/46 [==============================] - 27s 589ms/step - loss: 0.1281 - accuracy: 0.9523 - val_loss: 0.1940 - val_accuracy: 0.9312
# Epoch 76/98
# 46/46 [==============================] - 27s 586ms/step - loss: 0.1388 - accuracy: 0.9488 - val_loss: 0.1925 - val_accuracy: 0.9312
# Epoch 77/98
# 46/46 [==============================] - 27s 592ms/step - loss: 0.1174 - accuracy: 0.9611 - val_loss: 0.1939 - val_accuracy: 0.9438
# Epoch 78/98
# 46/46 [==============================] - 27s 576ms/step - loss: 0.1127 - accuracy: 0.9632 - val_loss: 0.1825 - val_accuracy: 0.9250
# Epoch 79/98
# 46/46 [==============================] - 27s 587ms/step - loss: 0.1220 - accuracy: 0.9591 - val_loss: 0.1783 - val_accuracy: 0.9312
# Epoch 80/98
# 46/46 [==============================] - 27s 581ms/step - loss: 0.1144 - accuracy: 0.9598 - val_loss: 0.1942 - val_accuracy: 0.9375
# Epoch 81/98
# 46/46 [==============================] - 27s 593ms/step - loss: 0.1170 - accuracy: 0.9577 - val_loss: 0.1803 - val_accuracy: 0.9250
# Epoch 82/98
# 46/46 [==============================] - 27s 576ms/step - loss: 0.1217 - accuracy: 0.9550 - val_loss: 0.1872 - val_accuracy: 0.9500
# Epoch 83/98
# 46/46 [==============================] - 27s 584ms/step - loss: 0.1028 - accuracy: 0.9632 - val_loss: 0.1859 - val_accuracy: 0.9375
# Epoch 84/98
# 46/46 [==============================] - 27s 589ms/step - loss: 0.1159 - accuracy: 0.9557 - val_loss: 0.1888 - val_accuracy: 0.9312
# Epoch 85/98
# 46/46 [==============================] - 27s 581ms/step - loss: 0.1150 - accuracy: 0.9611 - val_loss: 0.1769 - val_accuracy: 0.9375
# Epoch 86/98
# 46/46 [==============================] - 27s 595ms/step - loss: 0.1276 - accuracy: 0.9536 - val_loss: 0.1708 - val_accuracy: 0.9375
# Epoch 87/98
# 46/46 [==============================] - 27s 590ms/step - loss: 0.1109 - accuracy: 0.9611 - val_loss: 0.1950 - val_accuracy: 0.9250
# Epoch 88/98
# 46/46 [==============================] - 27s 588ms/step - loss: 0.1285 - accuracy: 0.9591 - val_loss: 0.1708 - val_accuracy: 0.9312
# Epoch 89/98
# 46/46 [==============================] - 28s 602ms/step - loss: 0.1137 - accuracy: 0.9645 - val_loss: 0.1572 - val_accuracy: 0.9438
# Epoch 90/98
# 46/46 [==============================] - 27s 595ms/step - loss: 0.1154 - accuracy: 0.9584 - val_loss: 0.1680 - val_accuracy: 0.9375
# Epoch 91/98
# 46/46 [==============================] - 27s 587ms/step - loss: 0.1033 - accuracy: 0.9652 - val_loss: 0.1722 - val_accuracy: 0.9312
# Epoch 92/98
# 46/46 [==============================] - 27s 583ms/step - loss: 0.1180 - accuracy: 0.9577 - val_loss: 0.1969 - val_accuracy: 0.9250
# Epoch 93/98
# 46/46 [==============================] - 27s 589ms/step - loss: 0.1277 - accuracy: 0.9529 - val_loss: 0.1754 - val_accuracy: 0.9312
# Epoch 94/98
# 46/46 [==============================] - 27s 584ms/step - loss: 0.1030 - accuracy: 0.9673 - val_loss: 0.1876 - val_accuracy: 0.9375
# Epoch 95/98
# 46/46 [==============================] - 27s 579ms/step - loss: 0.1097 - accuracy: 0.9604 - val_loss: 0.1792 - val_accuracy: 0.9312
# Epoch 96/98
# 46/46 [==============================] - 27s 580ms/step - loss: 0.1179 - accuracy: 0.9584 - val_loss: 0.1763 - val_accuracy: 0.9375
# Epoch 97/98
# 46/46 [==============================] - 27s 587ms/step - loss: 0.1144 - accuracy: 0.9638 - val_loss: 0.1917 - val_accuracy: 0.9375
# Epoch 98/98
# 46/46 [==============================] - 27s 577ms/step - loss: 0.1013 - accuracy: 0.9659 - val_loss: 0.1866 - val_accuracy: 0.9375

# %%
scores = VGG16_model.evaluate(test_ds)
print(f"Test Accuracy: {round(scores[1],4)*100}%")
# Out:
# 7/7 [==============================] - 8s 168ms/step - loss: 0.2182 - accuracy: 0.9241
# Test Accuracy: 92.41%

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
EPOCHS = len(acc)

plt.figure(figsize=(8, 5))
plt.subplot(1, 2, 1)
plt.plot(range(EPOCHS), acc, label='Training Accuracy', color='blue')
plt.plot(range(EPOCHS), val_acc, label='Validation Accuracy', color='orange')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.grid(True)
plt.show()

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']
EPOCHS = len(loss)  # Assuming loss and val_loss have the same length
plt.figure(figsize=(8, 5))
plt.subplot(1, 2, 2)
plt.plot(range(EPOCHS), loss, label='Training Loss', color='blue')
plt.plot(range(EPOCHS), val_loss, label='Validation Loss', color='orange')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.grid(True)
plt.show()

# %%
# Make predictions using the model
predictions = VGG16_model.predict(test_ds)
# Get the predicted class labels
predicted_labels = [np.argmax(prediction) for prediction in predictions]
test_labels = []
for images, labels in test_ds:
    test_labels.extend(labels.numpy())
test_labels = np.array(test_labels)
confusion = confusion_matrix(test_labels, predicted_labels)

print("Confusion Matrix:")
print(confusion)

# %%
def plot_confusion_matrix(confusion_matrix, class_names):
    plt.figure(figsize=(5, 4))
    sns.heatmap(confusion_matrix, annot=True, fmt='d', cmap='PuBu', xticklabels=class_names, yticklabels=class_names)
    plt.xlabel('Predicted')
    plt.ylabel('Actual')
    plt.title('Confusion Matrix')
    plt.show()

plot_confusion_matrix(confusion, class_names)

# %%
from sklearn.metrics import classification_report
test_labels = []  # True labels
predicted_labels = []  # Predicted labels

for images_batch, labels_batch in test_ds:
    batch_prediction = VGG16_model.predict(images_batch)
    predicted_labels.extend(np.argmax(batch_prediction, axis=1))
    test_labels.extend(labels_batch.numpy())
report = classification_report(test_labels, predicted_labels, target_names=class_names)
print(report)
# Out:
# 1/1 [==============================] - 0s 164ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 37ms/step
#                        precision    recall  f1-score   support
#
# Bacterial_leaf_blight       0.93      0.86      0.89        29
#            Brown_spot       0.95      0.84      0.89        44
#          Healthy_leaf       0.86      0.95      0.90        38
#            Leaf_Blast       0.89      0.97      0.93        34
#                 Other       1.00      1.00      1.00        50
#                Tungro       0.90      0.90      0.90        29
#
#              accuracy                           0.92       224
#             macro avg       0.92      0.92      0.92       224
#          weighted avg       0.93      0.92      0.92       224

# %%
for images_batch, labels_batch in test_ds.take(1):
    first_image = images_batch[0].numpy().astype('uint8')
    first_label = labels_batch[0].numpy()
    print("first image to predict")
    plt.imshow(first_image)
    print("actual label:",class_names[first_label])
    batch_prediction = VGG16_model.predict(images_batch)
    print("predicted label:",class_names[np.argmax(batch_prediction[0])])
# Out:
# first image to predict
# actual label: Healthy_leaf
# 1/1 [==============================] - 0s 38ms/step
# predicted label: Healthy_leaf
