# %%
pip install seaborn matplotlib
# Out:
# Requirement already satisfied: seaborn in /usr/local/lib/python3.10/dist-packages (0.13.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.7.1)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /usr/local/lib/python3.10/dist-packages (from seaborn) (1.25.2)
# Requirement already satisfied: pandas>=1.2 in /usr/local/lib/python3.10/dist-packages (from seaborn) (1.5.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.49.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.2->seaborn) (2023.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
import keras
import pandas as pd
import numpy as np
import itertools
import seaborn as sns
from sklearn import svm
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.metrics import f1_score
from sklearn.metrics import auc
from keras.models import Sequential
from tensorflow.keras import models, layers
from sklearn.metrics import confusion_matrix
from tensorflow.keras.applications import VGG16
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import roc_curve, roc_auc_score
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import average_precision_score
from tensorflow.keras.utils import plot_model
from tensorflow.keras.applications import InceptionV3
from tensorflow.keras.optimizers.schedules import ExponentialDecay
from keras. layers import Activation, Dropout, Flatten, Dense
from sklearn.model_selection import train_test_split, cross_val_score
from keras.layers import Conv1D, MaxPooling2D, MaxPooling1D, BatchNormalization
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
import warnings
warnings.filterwarnings('ignore')
def ignore_warn(*args, **kwargs):
  pass
  warnings.warn=ignore_warn

# %%
BATCH_SIZE = 32
IMAGE_SIZE = 300
CHANNELS=3
EPOCHS=98

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
dataset = tf.keras.preprocessing.image_dataset_from_directory(
    "/content/drive/MyDrive/Final_Dataset(RLDD)",
    seed=123,
    shuffle=True,
    image_size=(IMAGE_SIZE,IMAGE_SIZE),
    batch_size=BATCH_SIZE
)
# Out:
# Found 1850 files belonging to 6 classes.

# %%
class_names = dataset.class_names
class_names
# Out:
# ['Bacterial_leaf_blight',
#  'Brown_spot',
#  'Healthy_leaf',
#  'Leaf_Blast',
#  'Other',
#  'Tungro']

# %%
for image_batch, labels_batch in dataset.take(1):
    print(image_batch.shape)
    print(labels_batch.numpy())
# Out:
# (32, 300, 300, 3)
# [5 4 0 3 2 2 1 3 2 5 0 4 4 1 4 4 3 2 2 4 3 5 2 3 1 1 2 2 1 2 4 2]

# %%
new_image_size = (256, 256)
resized_dataset = dataset.map(lambda x, y: (tf.image.resize(x, new_image_size), y))
for image_batch, labels_batch in resized_dataset.take(1):
    print(image_batch.shape)
# Out:
# (32, 256, 256, 3)

# %%
import random
# Assuming you have a list of colors corresponding to each class
class_colors = [f'#{random.randint(0, 0xFFFFFF):06x}' for _ in class_names]

class_counts = [0] * len(class_names)
for images_batch, labels_batch in resized_dataset:# resized_dataset
    for label in labels_batch:
        class_counts[label] += 1

plt.figure(figsize=(6, 6))
patches, texts, autotexts = plt.pie(class_counts,
                                   autopct='%1.1f%%', startangle=140, colors=class_colors)

plt.legend(patches, class_names, loc='center left', bbox_to_anchor=(1, 0.5))

plt.title("Class Label Distribution")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Create a list to store the count of each class label
class_counts = [0] * len(class_names)
for images_batch, labels_batch in resized_dataset:
    for label in labels_batch:
        class_counts[label] += 1

# Plotting the bar chart
plt.figure(figsize=(10, 6))
plt.bar(class_names, class_counts, color='skyblue')
plt.title("Class Label Distribution")
plt.xlabel("Class Labels")
plt.ylabel("Count")
plt.xticks(rotation=45, ha="right")
plt.show()

# %%
plt.figure(figsize=(10, 10))
for image_batch, label_batch in resized_dataset.take(1):
  for i in range(12):
    ax = plt.subplot(3,4,i+1)
    plt.imshow(image_batch[i].numpy().astype("uint8"))
    plt.title(class_names[label_batch[i]])
    plt.axis("off")
  #print(image_batch[0].shape)

# %%
train_size = 0.8
len(resized_dataset)*train_size
# Out:
# 46.400000000000006

# %%
train_ds= resized_dataset.take(46)
len(train_ds)
# Out:
# 46

# %%
test_ds = resized_dataset.skip(46)
len(test_ds)
# Out:
# 12

# %%
val_size = 0.1
len(resized_dataset)*val_size
# Out:
# 5.800000000000001

# %%
val_ds = test_ds.take(6)
len(val_ds)
# Out:
# 6

# %%
test_ds = test_ds.skip(6)
len(test_ds)
# Out:
# 6

# %%
def get_dataset_partitions_tf(ds, train_split=0.8, val_split=0.1, test_split=0.1, shuffle=True, shuffle_size=10000):
    assert (train_split + test_split + val_split) == 1
    ds_size = len(ds)
    if shuffle:
      ds = ds.shuffle(shuffle_size, seed=12)
      train_size = int(train_split * ds_size)
      val_size = int(val_split * ds_size)
      train_ds = ds.take(train_size)
      val_ds = ds.skip(train_size).take(val_size)
      test_ds = ds.skip(train_size).skip(val_size)
      return train_ds, val_ds, test_ds

# %%
train_ds, val_ds, test_ds = get_dataset_partitions_tf(resized_dataset)

# %%
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)
val_ds = val_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)
test_ds = test_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)

# %%
resize_and_rescale = tf.keras.Sequential([
  layers.experimental.preprocessing.Resizing(256, 256),
  layers.experimental.preprocessing.Rescaling(1./255),
])

# %%
data_augmentation = tf.keras.Sequential([
  layers.experimental.preprocessing.RandomFlip("horizontal_and_vertical",dtype=tf.float32),  # Explicitly set data type
    # ... other preprocessing layers
  layers.experimental.preprocessing.RandomRotation(0.2),
  layers.experimental.preprocessing.RandomZoom(0.1),
  layers.experimental.preprocessing.RandomContrast(0.2),
])

# %%
train_ds = train_ds.map(
    lambda x, y: (data_augmentation(x, training=True), y)
).prefetch(buffer_size=tf.data.AUTOTUNE)

# %%
input_shape = (256, 256, CHANNELS)
n_classes = 6
CHANNELS = 3
# Load the InceptionV3 model
inception_model = InceptionV3(weights='imagenet', include_top=False, input_shape=input_shape)

# Freeze the InceptionV3 layers
for layer in inception_model.layers:
    layer.trainable = False

inceptionv3_model = tf.keras.Sequential([
    layers.Input(shape=(256, 256, CHANNELS)),
    #data_augmentation,
    inception_model,
    layers.GlobalAveragePooling2D(),
    layers.Dense(n_classes, activation='softmax')
])
inceptionv3_model.build(input_shape=input_shape)
inceptionv3_model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87910968/87910968 [==============================] - 1s 0us/step
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  inception_v3 (Functional)   (None, 6, 6, 2048)        21802784
#
#  global_average_pooling2d (  (None, 2048)              0
#  GlobalAveragePooling2D)
#
#  dense (Dense)               (None, 6)                 12294
#
# =================================================================
# Total params: 21815078 (83.22 MB)
# Trainable params: 12294 (48.02 KB)
# Non-trainable params: 21802784 (83.17 MB)
# _________________________________________________________________

# %%
plot_model(inceptionv3_model, to_file='inceptionv3_model.png', show_shapes=True)

# %%
from tensorflow.keras.optimizers.schedules import ExponentialDecay
initial_learning_rate = 0.001
lr_schedule = ExponentialDecay(
    initial_learning_rate, decay_steps=1000, decay_rate=0.9, staircase=True
    )

# %%
inceptionv3_model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=lr_schedule),
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
    metrics=['accuracy']
)

# %%
#tf.config.run_functions_eagerly(True)
history = inceptionv3_model.fit(
    train_ds,
    batch_size=BATCH_SIZE,
    validation_data=val_ds,
    verbose=1,
    epochs=EPOCHS,
)
# Out:
# Epoch 1/98
# 46/46 [==============================] - 210s 746ms/step - loss: 10.6299 - accuracy: 0.3608 - val_loss: 6.4977 - val_accuracy: 0.5063
# Epoch 2/98
# 46/46 [==============================] - 24s 531ms/step - loss: 5.2643 - accuracy: 0.4632 - val_loss: 4.3637 - val_accuracy: 0.4375
# Epoch 3/98
# 46/46 [==============================] - 24s 513ms/step - loss: 4.0809 - accuracy: 0.4857 - val_loss: 4.0499 - val_accuracy: 0.5063
# Epoch 4/98
# 46/46 [==============================] - 24s 510ms/step - loss: 3.8209 - accuracy: 0.5211 - val_loss: 5.6866 - val_accuracy: 0.4875
# Epoch 5/98
# 46/46 [==============================] - 28s 612ms/step - loss: 3.7176 - accuracy: 0.5068 - val_loss: 3.8375 - val_accuracy: 0.5125
# Epoch 6/98
# 46/46 [==============================] - 30s 658ms/step - loss: 3.2715 - accuracy: 0.5375 - val_loss: 2.6208 - val_accuracy: 0.5750
# Epoch 7/98
# 46/46 [==============================] - 34s 733ms/step - loss: 3.2640 - accuracy: 0.5280 - val_loss: 3.5509 - val_accuracy: 0.4875
# Epoch 8/98
# 46/46 [==============================] - 24s 528ms/step - loss: 3.5382 - accuracy: 0.5396 - val_loss: 5.0951 - val_accuracy: 0.4688
# Epoch 9/98
# 46/46 [==============================] - 25s 541ms/step - loss: 3.8094 - accuracy: 0.5334 - val_loss: 2.9252 - val_accuracy: 0.5250
# Epoch 10/98
# 46/46 [==============================] - 26s 557ms/step - loss: 3.2614 - accuracy: 0.5402 - val_loss: 2.8372 - val_accuracy: 0.5938
# Epoch 11/98
# 46/46 [==============================] - 23s 502ms/step - loss: 2.4803 - accuracy: 0.5798 - val_loss: 2.5643 - val_accuracy: 0.4812
# Epoch 12/98
# 46/46 [==============================] - 25s 539ms/step - loss: 2.4574 - accuracy: 0.5662 - val_loss: 4.3143 - val_accuracy: 0.5562
# Epoch 13/98
# 46/46 [==============================] - 24s 516ms/step - loss: 3.1777 - accuracy: 0.5464 - val_loss: 2.8479 - val_accuracy: 0.6250
# Epoch 14/98
# 46/46 [==============================] - 24s 515ms/step - loss: 2.3543 - accuracy: 0.5696 - val_loss: 2.0104 - val_accuracy: 0.6438
# Epoch 15/98
# 46/46 [==============================] - 25s 534ms/step - loss: 3.3353 - accuracy: 0.5518 - val_loss: 3.5442 - val_accuracy: 0.4313
# Epoch 16/98
# 46/46 [==============================] - 24s 509ms/step - loss: 2.9369 - accuracy: 0.5689 - val_loss: 2.0527 - val_accuracy: 0.6313
# Epoch 17/98
# 46/46 [==============================] - 24s 518ms/step - loss: 2.6282 - accuracy: 0.5662 - val_loss: 1.9230 - val_accuracy: 0.6375
# Epoch 18/98
# 46/46 [==============================] - 24s 518ms/step - loss: 2.8816 - accuracy: 0.5621 - val_loss: 4.2402 - val_accuracy: 0.4812
# Epoch 19/98
# 46/46 [==============================] - 25s 532ms/step - loss: 2.7820 - accuracy: 0.5600 - val_loss: 2.3252 - val_accuracy: 0.5688
# Epoch 20/98
# 46/46 [==============================] - 23s 509ms/step - loss: 2.6495 - accuracy: 0.5791 - val_loss: 1.9308 - val_accuracy: 0.5562
# Epoch 21/98
# 46/46 [==============================] - 24s 515ms/step - loss: 2.1162 - accuracy: 0.6023 - val_loss: 1.4862 - val_accuracy: 0.6500
# Epoch 22/98
# 46/46 [==============================] - 24s 522ms/step - loss: 2.7526 - accuracy: 0.5696 - val_loss: 3.3721 - val_accuracy: 0.4500
# Epoch 23/98
# 46/46 [==============================] - 24s 521ms/step - loss: 2.6378 - accuracy: 0.5873 - val_loss: 1.8792 - val_accuracy: 0.6000
# Epoch 24/98
# 46/46 [==============================] - 24s 523ms/step - loss: 2.2230 - accuracy: 0.5914 - val_loss: 1.7752 - val_accuracy: 0.6062
# Epoch 25/98
# 46/46 [==============================] - 24s 527ms/step - loss: 2.2906 - accuracy: 0.5900 - val_loss: 2.1436 - val_accuracy: 0.6438
# Epoch 26/98
# 46/46 [==============================] - 24s 520ms/step - loss: 2.0759 - accuracy: 0.5880 - val_loss: 1.7896 - val_accuracy: 0.6313
# Epoch 27/98
# 46/46 [==============================] - 24s 517ms/step - loss: 2.3518 - accuracy: 0.5914 - val_loss: 1.4927 - val_accuracy: 0.6313
# Epoch 28/98
# 46/46 [==============================] - 24s 520ms/step - loss: 2.1732 - accuracy: 0.5962 - val_loss: 1.2874 - val_accuracy: 0.6125
# Epoch 29/98
# 46/46 [==============================] - 24s 516ms/step - loss: 2.0806 - accuracy: 0.6091 - val_loss: 2.0856 - val_accuracy: 0.6250
# Epoch 30/98
# 46/46 [==============================] - 24s 520ms/step - loss: 2.0890 - accuracy: 0.5989 - val_loss: 2.0622 - val_accuracy: 0.6000
# Epoch 31/98
# 46/46 [==============================] - 24s 526ms/step - loss: 2.3713 - accuracy: 0.5846 - val_loss: 3.3312 - val_accuracy: 0.5625
# Epoch 32/98
# 46/46 [==============================] - 24s 526ms/step - loss: 2.5250 - accuracy: 0.5914 - val_loss: 1.3808 - val_accuracy: 0.6750
# Epoch 33/98
# 46/46 [==============================] - 24s 526ms/step - loss: 2.2268 - accuracy: 0.6003 - val_loss: 1.8124 - val_accuracy: 0.6000
# Epoch 34/98
# 46/46 [==============================] - 23s 507ms/step - loss: 2.2822 - accuracy: 0.6098 - val_loss: 2.9423 - val_accuracy: 0.6562
# Epoch 35/98
# 46/46 [==============================] - 24s 526ms/step - loss: 2.2168 - accuracy: 0.6105 - val_loss: 1.5723 - val_accuracy: 0.6375
# Epoch 36/98
# 46/46 [==============================] - 24s 526ms/step - loss: 1.6968 - accuracy: 0.6357 - val_loss: 1.8960 - val_accuracy: 0.6187
# Epoch 37/98
# 46/46 [==============================] - 24s 515ms/step - loss: 2.7444 - accuracy: 0.5778 - val_loss: 1.6146 - val_accuracy: 0.6313
# Epoch 38/98
# 46/46 [==============================] - 25s 536ms/step - loss: 2.2380 - accuracy: 0.6153 - val_loss: 1.4993 - val_accuracy: 0.6125
# Epoch 39/98
# 46/46 [==============================] - 24s 527ms/step - loss: 2.4681 - accuracy: 0.6037 - val_loss: 1.5456 - val_accuracy: 0.6438
# Epoch 40/98
# 46/46 [==============================] - 24s 515ms/step - loss: 2.0461 - accuracy: 0.6262 - val_loss: 1.6133 - val_accuracy: 0.6562
# Epoch 41/98
# 46/46 [==============================] - 24s 523ms/step - loss: 2.0465 - accuracy: 0.6078 - val_loss: 1.8171 - val_accuracy: 0.6062
# Epoch 42/98
# 46/46 [==============================] - 24s 523ms/step - loss: 1.7808 - accuracy: 0.6392 - val_loss: 2.1006 - val_accuracy: 0.6000
# Epoch 43/98
# 46/46 [==============================] - 24s 517ms/step - loss: 1.8784 - accuracy: 0.6337 - val_loss: 1.9610 - val_accuracy: 0.5125
# Epoch 44/98
# 46/46 [==============================] - 25s 533ms/step - loss: 2.0076 - accuracy: 0.6173 - val_loss: 2.2461 - val_accuracy: 0.5312
# Epoch 45/98
# 46/46 [==============================] - 25s 533ms/step - loss: 1.9256 - accuracy: 0.6310 - val_loss: 1.6259 - val_accuracy: 0.6187
# Epoch 46/98
# 46/46 [==============================] - 24s 512ms/step - loss: 1.4743 - accuracy: 0.6432 - val_loss: 1.1258 - val_accuracy: 0.6687
# Epoch 47/98
# 46/46 [==============================] - 24s 515ms/step - loss: 1.7915 - accuracy: 0.6166 - val_loss: 2.3873 - val_accuracy: 0.4812
# Epoch 48/98
# 46/46 [==============================] - 24s 510ms/step - loss: 1.7355 - accuracy: 0.6303 - val_loss: 1.9661 - val_accuracy: 0.5125
# Epoch 49/98
# 46/46 [==============================] - 24s 519ms/step - loss: 2.0424 - accuracy: 0.6119 - val_loss: 2.1120 - val_accuracy: 0.6250
# Epoch 50/98
# 46/46 [==============================] - 24s 518ms/step - loss: 1.5820 - accuracy: 0.6535 - val_loss: 0.9129 - val_accuracy: 0.6812
# Epoch 51/98
# 46/46 [==============================] - 24s 522ms/step - loss: 1.8004 - accuracy: 0.6330 - val_loss: 1.7591 - val_accuracy: 0.5750
# Epoch 52/98
# 46/46 [==============================] - 24s 520ms/step - loss: 1.4063 - accuracy: 0.6480 - val_loss: 1.3826 - val_accuracy: 0.6625
# Epoch 53/98
# 46/46 [==============================] - 24s 517ms/step - loss: 1.7919 - accuracy: 0.6255 - val_loss: 1.6483 - val_accuracy: 0.6250
# Epoch 54/98
# 46/46 [==============================] - 24s 526ms/step - loss: 1.8099 - accuracy: 0.6385 - val_loss: 2.3458 - val_accuracy: 0.6313
# Epoch 55/98
# 46/46 [==============================] - 23s 503ms/step - loss: 2.0796 - accuracy: 0.6235 - val_loss: 2.5056 - val_accuracy: 0.5813
# Epoch 56/98
# 46/46 [==============================] - 24s 510ms/step - loss: 1.8869 - accuracy: 0.6207 - val_loss: 1.5607 - val_accuracy: 0.6687
# Epoch 57/98
# 46/46 [==============================] - 23s 503ms/step - loss: 1.8672 - accuracy: 0.6323 - val_loss: 1.4552 - val_accuracy: 0.7063
# Epoch 58/98
# 46/46 [==============================] - 24s 518ms/step - loss: 1.8639 - accuracy: 0.6282 - val_loss: 0.9635 - val_accuracy: 0.7000
# Epoch 59/98
# 46/46 [==============================] - 23s 509ms/step - loss: 2.2061 - accuracy: 0.5948 - val_loss: 1.3246 - val_accuracy: 0.6438
# Epoch 60/98
# 46/46 [==============================] - 23s 503ms/step - loss: 2.2056 - accuracy: 0.6098 - val_loss: 1.3589 - val_accuracy: 0.6687
# Epoch 61/98
# 46/46 [==============================] - 23s 507ms/step - loss: 2.1369 - accuracy: 0.6296 - val_loss: 2.8703 - val_accuracy: 0.5875
# Epoch 62/98
# 46/46 [==============================] - 23s 510ms/step - loss: 1.8338 - accuracy: 0.6542 - val_loss: 1.1757 - val_accuracy: 0.6687
# Epoch 63/98
# 46/46 [==============================] - 23s 507ms/step - loss: 1.7888 - accuracy: 0.6310 - val_loss: 2.1949 - val_accuracy: 0.5125
# Epoch 64/98
# 46/46 [==============================] - 24s 522ms/step - loss: 1.5388 - accuracy: 0.6555 - val_loss: 1.8405 - val_accuracy: 0.5750
# Epoch 65/98
# 46/46 [==============================] - 24s 519ms/step - loss: 1.7404 - accuracy: 0.6269 - val_loss: 1.2601 - val_accuracy: 0.6687
# Epoch 66/98
# 46/46 [==============================] - 23s 491ms/step - loss: 1.8134 - accuracy: 0.6126 - val_loss: 2.3434 - val_accuracy: 0.5875
# Epoch 67/98
# 46/46 [==============================] - 23s 504ms/step - loss: 1.8971 - accuracy: 0.6289 - val_loss: 1.1891 - val_accuracy: 0.6875
# Epoch 68/98
# 46/46 [==============================] - 23s 503ms/step - loss: 1.7923 - accuracy: 0.6501 - val_loss: 1.4728 - val_accuracy: 0.6313
# Epoch 69/98
# 46/46 [==============================] - 23s 506ms/step - loss: 1.5864 - accuracy: 0.6412 - val_loss: 1.1093 - val_accuracy: 0.6750
# Epoch 70/98
# 46/46 [==============================] - 23s 508ms/step - loss: 1.7004 - accuracy: 0.6426 - val_loss: 1.7609 - val_accuracy: 0.5938
# Epoch 71/98
# 46/46 [==============================] - 24s 516ms/step - loss: 1.6992 - accuracy: 0.6296 - val_loss: 1.1241 - val_accuracy: 0.7125
# Epoch 72/98
# 46/46 [==============================] - 24s 511ms/step - loss: 1.8589 - accuracy: 0.6310 - val_loss: 1.3515 - val_accuracy: 0.6562
# Epoch 73/98
# 46/46 [==============================] - 24s 511ms/step - loss: 1.4560 - accuracy: 0.6480 - val_loss: 1.3840 - val_accuracy: 0.7188
# Epoch 74/98
# 46/46 [==============================] - 23s 509ms/step - loss: 1.8222 - accuracy: 0.6214 - val_loss: 2.3514 - val_accuracy: 0.7125
# Epoch 75/98
# 46/46 [==============================] - 23s 508ms/step - loss: 1.8945 - accuracy: 0.6241 - val_loss: 2.1486 - val_accuracy: 0.6062
# Epoch 76/98
# 46/46 [==============================] - 24s 516ms/step - loss: 1.9236 - accuracy: 0.6330 - val_loss: 1.5503 - val_accuracy: 0.6375
# Epoch 77/98
# 46/46 [==============================] - 25s 530ms/step - loss: 2.0600 - accuracy: 0.6241 - val_loss: 1.5745 - val_accuracy: 0.5938
# Epoch 78/98
# 46/46 [==============================] - 23s 503ms/step - loss: 1.9455 - accuracy: 0.6241 - val_loss: 2.1664 - val_accuracy: 0.5063
# Epoch 79/98
# 46/46 [==============================] - 26s 573ms/step - loss: 2.0200 - accuracy: 0.6207 - val_loss: 1.4966 - val_accuracy: 0.6750
# Epoch 80/98
# 46/46 [==============================] - 34s 734ms/step - loss: 1.6614 - accuracy: 0.6514 - val_loss: 1.1713 - val_accuracy: 0.6750
# Epoch 81/98
# 46/46 [==============================] - 24s 519ms/step - loss: 1.4891 - accuracy: 0.6487 - val_loss: 1.4862 - val_accuracy: 0.6187
# Epoch 82/98
# 46/46 [==============================] - 23s 508ms/step - loss: 1.5758 - accuracy: 0.6317 - val_loss: 1.4087 - val_accuracy: 0.7375
# Epoch 83/98
# 46/46 [==============================] - 23s 503ms/step - loss: 1.6570 - accuracy: 0.6412 - val_loss: 2.0063 - val_accuracy: 0.6125
# Epoch 84/98
# 46/46 [==============================] - 23s 506ms/step - loss: 2.0454 - accuracy: 0.6241 - val_loss: 2.8495 - val_accuracy: 0.6687
# Epoch 85/98
# 46/46 [==============================] - 23s 503ms/step - loss: 1.9725 - accuracy: 0.6276 - val_loss: 0.8928 - val_accuracy: 0.7500
# Epoch 86/98
# 46/46 [==============================] - 23s 498ms/step - loss: 1.5155 - accuracy: 0.6528 - val_loss: 1.4765 - val_accuracy: 0.7500
# Epoch 87/98
# 46/46 [==============================] - 24s 509ms/step - loss: 1.4380 - accuracy: 0.6569 - val_loss: 1.1799 - val_accuracy: 0.6313
# Epoch 88/98
# 46/46 [==============================] - 23s 509ms/step - loss: 1.4367 - accuracy: 0.6617 - val_loss: 0.9718 - val_accuracy: 0.7125
# Epoch 89/98
# 46/46 [==============================] - 23s 505ms/step - loss: 1.4211 - accuracy: 0.6569 - val_loss: 1.6203 - val_accuracy: 0.6500
# Epoch 90/98
# 46/46 [==============================] - 24s 511ms/step - loss: 2.1098 - accuracy: 0.6044 - val_loss: 2.0427 - val_accuracy: 0.5125
# Epoch 91/98
# 46/46 [==============================] - 24s 513ms/step - loss: 1.8992 - accuracy: 0.6241 - val_loss: 1.6518 - val_accuracy: 0.6375
# Epoch 92/98
# 46/46 [==============================] - 23s 489ms/step - loss: 1.9636 - accuracy: 0.6146 - val_loss: 1.1095 - val_accuracy: 0.6750
# Epoch 93/98
# 46/46 [==============================] - 23s 504ms/step - loss: 1.6526 - accuracy: 0.6446 - val_loss: 1.5935 - val_accuracy: 0.6625
# Epoch 94/98
# 46/46 [==============================] - 24s 519ms/step - loss: 1.5486 - accuracy: 0.6548 - val_loss: 1.1451 - val_accuracy: 0.7437
# Epoch 95/98
# 46/46 [==============================] - 23s 503ms/step - loss: 1.4433 - accuracy: 0.6412 - val_loss: 0.9637 - val_accuracy: 0.7188
# Epoch 96/98
# 46/46 [==============================] - 23s 492ms/step - loss: 1.4747 - accuracy: 0.6371 - val_loss: 1.9619 - val_accuracy: 0.6250
# Epoch 97/98
# 46/46 [==============================] - 23s 508ms/step - loss: 2.0322 - accuracy: 0.6146 - val_loss: 1.4666 - val_accuracy: 0.6438
# Epoch 98/98
# 46/46 [==============================] - 23s 500ms/step - loss: 1.9459 - accuracy: 0.6351 - val_loss: 1.7730 - val_accuracy: 0.5875

# %%
scores = inceptionv3_model.evaluate(test_ds)
print(f"Test Accuracy: {round(scores[1],4)*100}%")
# Out:
# 7/7 [==============================] - 7s 89ms/step - loss: 1.9721 - accuracy: 0.6607
# Test Accuracy: 66.07%

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
EPOCHS = len(acc)

plt.figure(figsize=(8, 5))
plt.subplot(1, 2, 1)
plt.plot(range(EPOCHS), acc, label='Training Accuracy', color='blue')
plt.plot(range(EPOCHS), val_acc, label='Validation Accuracy', color='orange')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.grid(True)
plt.show()

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']
EPOCHS = len(loss)  # Assuming loss and val_loss have the same length
plt.figure(figsize=(8, 5))
plt.subplot(1, 2, 2)
plt.plot(range(EPOCHS), loss, label='Training Loss', color='blue')
plt.plot(range(EPOCHS), val_loss, label='Validation Loss', color='orange')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.show()

# %%
# Make predictions using the model
predictions = inceptionv3_model.predict(test_ds)
# Get the predicted class labels
predicted_labels = [np.argmax(prediction) for prediction in predictions]
test_labels = []
for images, labels in test_ds:
    test_labels.extend(labels.numpy())
test_labels = np.array(test_labels)
confusion = confusion_matrix(test_labels, predicted_labels)

print("Confusion Matrix:")
print(confusion)
# Out:
# 7/7 [==============================] - 1s 96ms/step
# Confusion Matrix:
# [[ 3 12  3  3  7  1]
#  [ 1 24  3  6  9  1]
#  [ 2 14 11  2  8  1]
#  [ 2  5  0 15  9  3]
#  [ 1  5  4  9 30  1]
#  [ 1 11  3  3  6  5]]

# %%
def plot_confusion_matrix(confusion_matrix, class_names):
    plt.figure(figsize=(5, 4))
    sns.heatmap(confusion_matrix, annot=True, fmt='d', cmap='Oranges', xticklabels=class_names, yticklabels=class_names)
    plt.xlabel('Predicted')
    plt.ylabel('Actual')
    plt.title('Confusion Matrix')
    plt.show()

# Call the function to display the confusion matrix
plot_confusion_matrix(confusion, class_names)

# %%
from sklearn.metrics import classification_report
test_labels = []  # True labels
predicted_labels = []  # Predicted labels

for images_batch, labels_batch in test_ds:
    batch_prediction = inceptionv3_model.predict(images_batch)
    predicted_labels.extend(np.argmax(batch_prediction, axis=1))
    test_labels.extend(labels_batch.numpy())
report = classification_report(test_labels, predicted_labels, target_names=class_names)
print(report)
# Out:
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 36ms/step
#                        precision    recall  f1-score   support
#
# Bacterial_leaf_blight       0.70      0.24      0.36        29
#            Brown_spot       0.46      0.75      0.57        44
#          Healthy_leaf       0.79      0.50      0.61        38
#            Leaf_Blast       0.74      0.82      0.78        34
#                 Other       0.71      0.98      0.82        50
#                Tungro       1.00      0.41      0.59        29
#
#              accuracy                           0.66       224
#             macro avg       0.73      0.62      0.62       224
#          weighted avg       0.72      0.66      0.64       224

# %%
for images_batch, labels_batch in test_ds.take(1):

    first_image = images_batch[0].numpy().astype('uint8')
    first_label = labels_batch[0].numpy()

    print("first image to predict")
    plt.imshow(first_image)
    print("actual label:",class_names[first_label])

    batch_prediction = inceptionv3_model.predict(images_batch)
    print("predicted label:",class_names[np.argmax(batch_prediction[0])])
# Out:
# first image to predict
# actual label: Bacterial_leaf_blight
# 1/1 [==============================] - 0s 54ms/step
# predicted label: Brown_spot
