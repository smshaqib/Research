# %%
pip install seaborn matplotlib
# Out:
# Requirement already satisfied: seaborn in /usr/local/lib/python3.10/dist-packages (0.13.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.7.1)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /usr/local/lib/python3.10/dist-packages (from seaborn) (1.25.2)
# Requirement already satisfied: pandas>=1.2 in /usr/local/lib/python3.10/dist-packages (from seaborn) (1.5.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.49.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.2->seaborn) (2023.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
import keras
import pandas as pd
import numpy as np
import itertools
import seaborn as sns
from sklearn import svm
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.metrics import f1_score
from sklearn.metrics import auc
from keras.models import Sequential
from tensorflow.keras import models, layers
from tensorflow.keras.utils import plot_model
from sklearn.metrics import confusion_matrix
from tensorflow.keras.applications import DenseNet201
from tensorflow.keras.optimizers.schedules import ExponentialDecay
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import roc_curve, roc_auc_score
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import average_precision_score
from keras. layers import Activation, Dropout, Flatten, Dense
from sklearn.model_selection import train_test_split, cross_val_score
from keras.layers import Conv1D, MaxPooling2D, MaxPooling1D, BatchNormalization
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
import warnings
warnings.filterwarnings('ignore')
def ignore_warn(*args, **kwargs):
  pass
  warnings.warn=ignore_warn

# %%
BATCH_SIZE = 32
IMAGE_SIZE = 300
CHANNELS=3
EPOCHS=98

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
dataset = tf.keras.preprocessing.image_dataset_from_directory(
    "/content/drive/MyDrive/Paddy Leaf Disease Detection/Final_Dataset(RLDD)",
    seed=123,
    shuffle=True,
    image_size=(IMAGE_SIZE,IMAGE_SIZE),
    batch_size=BATCH_SIZE
)
# Out:
# Found 1850 files belonging to 6 classes.

# %%
class_names = dataset.class_names
class_names
# Out:
# ['Bacterial_leaf_blight',
#  'Brown_spot',
#  'Healthy_leaf',
#  'Leaf_Blast',
#  'Other',
#  'Tungro']

# %%
for image_batch, labels_batch in dataset.take(1):
    print(image_batch.shape)
    print(labels_batch.numpy())
# Out:
# (32, 300, 300, 3)
# [5 4 0 3 2 2 1 3 2 5 0 4 4 1 4 4 3 2 2 4 3 5 2 3 1 1 2 2 1 2 4 2]

# %%
len(dataset)
# Out:
# 58

# %%
new_image_size = (256, 256)
resized_dataset = dataset.map(lambda x, y: (tf.image.resize(x, new_image_size), y))
for image_batch, labels_batch in resized_dataset.take(1):
    print(image_batch.shape)
# Out:
# (32, 256, 256, 3)

# %%
import random
# Assuming you have a list of colors corresponding to each class
class_colors = [f'#{random.randint(0, 0xFFFFFF):06x}' for _ in class_names]

class_counts = [0] * len(class_names)
for images_batch, labels_batch in resized_dataset:# resized_dataset
    for label in labels_batch:
        class_counts[label] += 1

plt.figure(figsize=(6, 6))
patches, texts, autotexts = plt.pie(class_counts,
                                   autopct='%1.1f%%', startangle=140, colors=class_colors)

plt.legend(patches, class_names, loc='center left', bbox_to_anchor=(1, 0.5))

plt.title("Class Label Distribution")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Create a list to store the count of each class label
class_counts = [0] * len(class_names)
for images_batch, labels_batch in resized_dataset:
    for label in labels_batch:
        class_counts[label] += 1

# Plotting the bar chart
plt.figure(figsize=(10, 6))
plt.bar(class_names, class_counts, color='skyblue')
plt.title("Class Label Distribution")
plt.xlabel("Class Labels")
plt.ylabel("Count")
plt.xticks(rotation=45, ha="right")
plt.show()

# %%
plt.figure(figsize=(10, 10))
for image_batch, label_batch in resized_dataset.take(1):
  for i in range(12):
    ax = plt.subplot(3,4,i+1)
    plt.imshow(image_batch[i].numpy().astype("uint8"))
    plt.title(class_names[label_batch[i]])
    plt.axis("off")
  print(image_batch[0].shape)
# Out:
# (256, 256, 3)

# %%
train_size = 0.8
len(resized_dataset)*train_size
# Out:
# 46.400000000000006

# %%
train_ds= resized_dataset.take(46)
len(train_ds)
# Out:
# 46

# %%
test_ds = resized_dataset.skip(46)
len(test_ds)
# Out:
# 12

# %%
val_size = 0.1
len(resized_dataset)*val_size
# Out:
# 5.800000000000001

# %%
val_ds = test_ds.take(6)
len(val_ds)
# Out:
# 6

# %%
test_ds = test_ds.skip(6)
len(test_ds)
# Out:
# 6

# %%
def get_dataset_partitions_tf(ds, train_split=0.8, val_split=0.1, test_split=0.1, shuffle=True, shuffle_size=10000):
    assert (train_split + test_split + val_split) == 1
    ds_size = len(ds)
    if shuffle:
      ds = ds.shuffle(shuffle_size, seed=12)
      train_size = int(train_split * ds_size)
      val_size = int(val_split * ds_size)
      train_ds = ds.take(train_size)
      val_ds = ds.skip(train_size).take(val_size)
      test_ds = ds.skip(train_size).skip(val_size)
      return train_ds, val_ds, test_ds

# %%
train_ds, val_ds, test_ds = get_dataset_partitions_tf(resized_dataset)

# %%
len(train_ds)
# Out:
# 46

# %%
len(val_ds)
# Out:
# 5

# %%
len(test_ds)
# Out:
# 7

# %%
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)
val_ds = val_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)
test_ds = test_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)

# %%
resize_and_rescale = tf.keras.Sequential([
  layers.experimental.preprocessing.Resizing(256, 256),
  layers.experimental.preprocessing.Rescaling(1./255),
])

# %%
data_augmentation = tf.keras.Sequential([
  layers.experimental.preprocessing.RandomFlip("horizontal_and_vertical",dtype=tf.float32),  # Explicitly set data type
    # ... other preprocessing layers
  layers.experimental.preprocessing.RandomRotation(0.2),
  layers.experimental.preprocessing.RandomZoom(0.1),
  layers.experimental.preprocessing.RandomContrast(0.2),
])

# %%
train_ds = train_ds.map(
    lambda x, y: (data_augmentation(x, training=True), y)
).prefetch(buffer_size=tf.data.AUTOTUNE)

# %%
DenseNet201_model = DenseNet201(weights='imagenet', include_top=False, input_shape=(256, 256, CHANNELS))
for layer in DenseNet201_model.layers:
    layer.trainable = False

DenseNet201_model = tf.keras.Sequential([
    layers.Input(shape=(256, 256, CHANNELS)),
    DenseNet201_model,
    layers.GlobalAveragePooling2D(),
    layers.Dense(6, activation='softmax')
])

DenseNet201_model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet201_weights_tf_dim_ordering_tf_kernels_notop.h5
# 74836368/74836368 [==============================] - 4s 0us/step
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  densenet201 (Functional)    (None, 8, 8, 1920)        18321984
#
#  global_average_pooling2d (  (None, 1920)              0
#  GlobalAveragePooling2D)
#
#  dense (Dense)               (None, 6)                 11526
#
# =================================================================
# Total params: 18333510 (69.94 MB)
# Trainable params: 11526 (45.02 KB)
# Non-trainable params: 18321984 (69.89 MB)
# _________________________________________________________________

# %%
plot_model(DenseNet201_model, to_file='DenseNet201_model.png', show_shapes=True)

# %%
initial_learning_rate = 0.001
lr_schedule = ExponentialDecay(
    initial_learning_rate, decay_steps=1000, decay_rate=0.9, staircase=True
    )

# %%
DenseNet201_model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=lr_schedule),
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
    metrics=['accuracy']
)

# %%
history = DenseNet201_model.fit(
    train_ds,
    batch_size=BATCH_SIZE,
    validation_data=val_ds,
    verbose=1,
    epochs=EPOCHS,
)
# Out:
# Epoch 1/98
# 46/46 [==============================] - 443s 927ms/step - loss: 2.9360 - accuracy: 0.3643 - val_loss: 1.2041 - val_accuracy: 0.6000
# Epoch 2/98
# 46/46 [==============================] - 26s 566ms/step - loss: 1.0069 - accuracy: 0.6351 - val_loss: 1.0799 - val_accuracy: 0.5750
# Epoch 3/98
# 46/46 [==============================] - 26s 566ms/step - loss: 0.8580 - accuracy: 0.6787 - val_loss: 0.9068 - val_accuracy: 0.6687
# Epoch 4/98
# 46/46 [==============================] - 26s 568ms/step - loss: 0.7925 - accuracy: 0.7019 - val_loss: 0.7375 - val_accuracy: 0.7000
# Epoch 5/98
# 46/46 [==============================] - 26s 562ms/step - loss: 0.6828 - accuracy: 0.7578 - val_loss: 0.7020 - val_accuracy: 0.7375
# Epoch 6/98
# 46/46 [==============================] - 27s 580ms/step - loss: 0.6901 - accuracy: 0.7572 - val_loss: 0.6363 - val_accuracy: 0.7750
# Epoch 7/98
# 46/46 [==============================] - 26s 564ms/step - loss: 0.5741 - accuracy: 0.8049 - val_loss: 0.5617 - val_accuracy: 0.7875
# Epoch 8/98
# 46/46 [==============================] - 27s 577ms/step - loss: 0.6269 - accuracy: 0.7640 - val_loss: 0.7855 - val_accuracy: 0.7375
# Epoch 9/98
# 46/46 [==============================] - 26s 568ms/step - loss: 0.6011 - accuracy: 0.7879 - val_loss: 0.5765 - val_accuracy: 0.7875
# Epoch 10/98
# 46/46 [==============================] - 26s 562ms/step - loss: 0.5123 - accuracy: 0.8213 - val_loss: 0.6327 - val_accuracy: 0.8062
# Epoch 11/98
# 46/46 [==============================] - 27s 576ms/step - loss: 0.4951 - accuracy: 0.8267 - val_loss: 0.5131 - val_accuracy: 0.8000
# Epoch 12/98
# 46/46 [==============================] - 26s 561ms/step - loss: 0.5055 - accuracy: 0.8261 - val_loss: 0.4853 - val_accuracy: 0.8250
# Epoch 13/98
# 46/46 [==============================] - 26s 573ms/step - loss: 0.4700 - accuracy: 0.8417 - val_loss: 0.5574 - val_accuracy: 0.7875
# Epoch 14/98
# 46/46 [==============================] - 26s 561ms/step - loss: 0.4972 - accuracy: 0.8267 - val_loss: 0.4841 - val_accuracy: 0.8313
# Epoch 15/98
# 46/46 [==============================] - 27s 574ms/step - loss: 0.4562 - accuracy: 0.8417 - val_loss: 0.5176 - val_accuracy: 0.8062
# Epoch 16/98
# 46/46 [==============================] - 26s 567ms/step - loss: 0.4492 - accuracy: 0.8370 - val_loss: 0.5276 - val_accuracy: 0.7937
# Epoch 17/98
# 46/46 [==============================] - 25s 550ms/step - loss: 0.4485 - accuracy: 0.8479 - val_loss: 0.4859 - val_accuracy: 0.8313
# Epoch 18/98
# 46/46 [==============================] - 26s 570ms/step - loss: 0.4104 - accuracy: 0.8554 - val_loss: 0.3833 - val_accuracy: 0.8687
# Epoch 19/98
# 46/46 [==============================] - 27s 578ms/step - loss: 0.3936 - accuracy: 0.8643 - val_loss: 0.4747 - val_accuracy: 0.8125
# Epoch 20/98
# 46/46 [==============================] - 26s 555ms/step - loss: 0.3948 - accuracy: 0.8615 - val_loss: 0.4796 - val_accuracy: 0.8062
# Epoch 21/98
# 46/46 [==============================] - 26s 561ms/step - loss: 0.3811 - accuracy: 0.8683 - val_loss: 0.3839 - val_accuracy: 0.8438
# Epoch 22/98
# 46/46 [==============================] - 26s 564ms/step - loss: 0.4097 - accuracy: 0.8745 - val_loss: 0.4572 - val_accuracy: 0.8375
# Epoch 23/98
# 46/46 [==============================] - 26s 565ms/step - loss: 0.3620 - accuracy: 0.8752 - val_loss: 0.4102 - val_accuracy: 0.8375
# Epoch 24/98
# 46/46 [==============================] - 26s 559ms/step - loss: 0.3683 - accuracy: 0.8670 - val_loss: 0.3821 - val_accuracy: 0.8625
# Epoch 25/98
# 46/46 [==============================] - 26s 563ms/step - loss: 0.3499 - accuracy: 0.8738 - val_loss: 0.3526 - val_accuracy: 0.8562
# Epoch 26/98
# 46/46 [==============================] - 26s 571ms/step - loss: 0.3504 - accuracy: 0.8793 - val_loss: 0.4093 - val_accuracy: 0.8500
# Epoch 27/98
# 46/46 [==============================] - 26s 566ms/step - loss: 0.3440 - accuracy: 0.8847 - val_loss: 0.3079 - val_accuracy: 0.8813
# Epoch 28/98
# 46/46 [==============================] - 26s 570ms/step - loss: 0.3448 - accuracy: 0.8793 - val_loss: 0.3350 - val_accuracy: 0.8750
# Epoch 29/98
# 46/46 [==============================] - 26s 570ms/step - loss: 0.3516 - accuracy: 0.8799 - val_loss: 0.3238 - val_accuracy: 0.8813
# Epoch 30/98
# 46/46 [==============================] - 26s 562ms/step - loss: 0.3534 - accuracy: 0.8861 - val_loss: 0.5003 - val_accuracy: 0.8000
# Epoch 31/98
# 46/46 [==============================] - 26s 575ms/step - loss: 0.3398 - accuracy: 0.8779 - val_loss: 0.3132 - val_accuracy: 0.8813
# Epoch 32/98
# 46/46 [==============================] - 26s 576ms/step - loss: 0.3266 - accuracy: 0.8793 - val_loss: 0.3290 - val_accuracy: 0.8625
# Epoch 33/98
# 46/46 [==============================] - 26s 562ms/step - loss: 0.3284 - accuracy: 0.8861 - val_loss: 0.4277 - val_accuracy: 0.8188
# Epoch 34/98
# 46/46 [==============================] - 26s 564ms/step - loss: 0.3344 - accuracy: 0.8827 - val_loss: 0.3416 - val_accuracy: 0.8687
# Epoch 35/98
# 46/46 [==============================] - 26s 566ms/step - loss: 0.3197 - accuracy: 0.8915 - val_loss: 0.3161 - val_accuracy: 0.8875
# Epoch 36/98
# 46/46 [==============================] - 26s 567ms/step - loss: 0.3088 - accuracy: 0.8902 - val_loss: 0.3293 - val_accuracy: 0.8813
# Epoch 37/98
# 46/46 [==============================] - 26s 561ms/step - loss: 0.3407 - accuracy: 0.8806 - val_loss: 0.2964 - val_accuracy: 0.8750
# Epoch 38/98
# 46/46 [==============================] - 26s 562ms/step - loss: 0.3012 - accuracy: 0.8950 - val_loss: 0.3523 - val_accuracy: 0.8750
# Epoch 39/98
# 46/46 [==============================] - 26s 568ms/step - loss: 0.3118 - accuracy: 0.8950 - val_loss: 0.3700 - val_accuracy: 0.8625
# Epoch 40/98
# 46/46 [==============================] - 26s 560ms/step - loss: 0.2960 - accuracy: 0.9052 - val_loss: 0.3232 - val_accuracy: 0.8875
# Epoch 41/98
# 46/46 [==============================] - 26s 562ms/step - loss: 0.3184 - accuracy: 0.8827 - val_loss: 0.3341 - val_accuracy: 0.8625
# Epoch 42/98
# 46/46 [==============================] - 26s 568ms/step - loss: 0.3805 - accuracy: 0.8595 - val_loss: 0.3491 - val_accuracy: 0.8813
# Epoch 43/98
# 46/46 [==============================] - 26s 556ms/step - loss: 0.3143 - accuracy: 0.8813 - val_loss: 0.3514 - val_accuracy: 0.8750
# Epoch 44/98
# 46/46 [==============================] - 26s 567ms/step - loss: 0.2916 - accuracy: 0.8970 - val_loss: 0.3110 - val_accuracy: 0.8938
# Epoch 45/98
# 46/46 [==============================] - 26s 564ms/step - loss: 0.2879 - accuracy: 0.9004 - val_loss: 0.3156 - val_accuracy: 0.8813
# Epoch 46/98
# 46/46 [==============================] - 26s 569ms/step - loss: 0.2884 - accuracy: 0.8922 - val_loss: 0.3803 - val_accuracy: 0.8687
# Epoch 47/98
# 46/46 [==============================] - 26s 574ms/step - loss: 0.3347 - accuracy: 0.8793 - val_loss: 0.3077 - val_accuracy: 0.8938
# Epoch 48/98
# 46/46 [==============================] - 26s 570ms/step - loss: 0.2858 - accuracy: 0.8990 - val_loss: 0.3412 - val_accuracy: 0.8562
# Epoch 49/98
# 46/46 [==============================] - 26s 562ms/step - loss: 0.2734 - accuracy: 0.9031 - val_loss: 0.3243 - val_accuracy: 0.8938
# Epoch 50/98
# 46/46 [==============================] - 26s 559ms/step - loss: 0.2841 - accuracy: 0.8963 - val_loss: 0.3213 - val_accuracy: 0.8687
# Epoch 51/98
# 46/46 [==============================] - 26s 567ms/step - loss: 0.2990 - accuracy: 0.8909 - val_loss: 0.2972 - val_accuracy: 0.8813
# Epoch 52/98
# 46/46 [==============================] - 26s 569ms/step - loss: 0.2767 - accuracy: 0.8990 - val_loss: 0.3876 - val_accuracy: 0.8250
# Epoch 53/98
# 46/46 [==============================] - 26s 559ms/step - loss: 0.2743 - accuracy: 0.9065 - val_loss: 0.3614 - val_accuracy: 0.8562
# Epoch 54/98
# 46/46 [==============================] - 26s 561ms/step - loss: 0.2647 - accuracy: 0.9127 - val_loss: 0.3478 - val_accuracy: 0.8813
# Epoch 55/98
# 46/46 [==============================] - 26s 564ms/step - loss: 0.2870 - accuracy: 0.8909 - val_loss: 0.3108 - val_accuracy: 0.8813
# Epoch 56/98
# 46/46 [==============================] - 26s 571ms/step - loss: 0.2682 - accuracy: 0.9059 - val_loss: 0.3993 - val_accuracy: 0.8625
# Epoch 57/98
# 46/46 [==============================] - 26s 574ms/step - loss: 0.2750 - accuracy: 0.9093 - val_loss: 0.3236 - val_accuracy: 0.8813
# Epoch 58/98
# 46/46 [==============================] - 26s 573ms/step - loss: 0.2890 - accuracy: 0.8956 - val_loss: 0.3038 - val_accuracy: 0.8875
# Epoch 59/98
# 46/46 [==============================] - 26s 565ms/step - loss: 0.2525 - accuracy: 0.9175 - val_loss: 0.3573 - val_accuracy: 0.8687
# Epoch 60/98
# 46/46 [==============================] - 26s 570ms/step - loss: 0.2819 - accuracy: 0.8977 - val_loss: 0.4093 - val_accuracy: 0.8313
# Epoch 61/98
# 46/46 [==============================] - 27s 579ms/step - loss: 0.2674 - accuracy: 0.9086 - val_loss: 0.2962 - val_accuracy: 0.9187
# Epoch 62/98
# 46/46 [==============================] - 26s 561ms/step - loss: 0.2726 - accuracy: 0.9079 - val_loss: 0.3171 - val_accuracy: 0.8938
# Epoch 63/98
# 46/46 [==============================] - 26s 562ms/step - loss: 0.2616 - accuracy: 0.9175 - val_loss: 0.3191 - val_accuracy: 0.8813
# Epoch 64/98
# 46/46 [==============================] - 26s 565ms/step - loss: 0.2357 - accuracy: 0.9147 - val_loss: 0.3309 - val_accuracy: 0.8750
# Epoch 65/98
# 46/46 [==============================] - 26s 569ms/step - loss: 0.2784 - accuracy: 0.9011 - val_loss: 0.2679 - val_accuracy: 0.9062
# Epoch 66/98
# 46/46 [==============================] - 26s 568ms/step - loss: 0.2637 - accuracy: 0.9059 - val_loss: 0.3798 - val_accuracy: 0.8750
# Epoch 67/98
# 46/46 [==============================] - 26s 569ms/step - loss: 0.2428 - accuracy: 0.9059 - val_loss: 0.3045 - val_accuracy: 0.8813
# Epoch 68/98
# 46/46 [==============================] - 26s 575ms/step - loss: 0.2729 - accuracy: 0.9018 - val_loss: 0.3774 - val_accuracy: 0.8687
# Epoch 69/98
# 46/46 [==============================] - 26s 560ms/step - loss: 0.2657 - accuracy: 0.9079 - val_loss: 0.3281 - val_accuracy: 0.8750
# Epoch 70/98
# 46/46 [==============================] - 26s 564ms/step - loss: 0.2587 - accuracy: 0.9065 - val_loss: 0.3864 - val_accuracy: 0.8813
# Epoch 71/98
# 46/46 [==============================] - 26s 563ms/step - loss: 0.2340 - accuracy: 0.9168 - val_loss: 0.3996 - val_accuracy: 0.8750
# Epoch 72/98
# 46/46 [==============================] - 26s 562ms/step - loss: 0.2411 - accuracy: 0.9181 - val_loss: 0.3585 - val_accuracy: 0.8625
# Epoch 73/98
# 46/46 [==============================] - 26s 564ms/step - loss: 0.2403 - accuracy: 0.9079 - val_loss: 0.2746 - val_accuracy: 0.8875
# Epoch 74/98
# 46/46 [==============================] - 26s 563ms/step - loss: 0.2501 - accuracy: 0.9120 - val_loss: 0.2756 - val_accuracy: 0.9062
# Epoch 75/98
# 46/46 [==============================] - 26s 568ms/step - loss: 0.2730 - accuracy: 0.8990 - val_loss: 0.3350 - val_accuracy: 0.8875
# Epoch 76/98
# 46/46 [==============================] - 26s 563ms/step - loss: 0.2394 - accuracy: 0.9120 - val_loss: 0.2927 - val_accuracy: 0.9000
# Epoch 77/98
# 46/46 [==============================] - 26s 571ms/step - loss: 0.2563 - accuracy: 0.9093 - val_loss: 0.3075 - val_accuracy: 0.8813
# Epoch 78/98
# 46/46 [==============================] - 27s 579ms/step - loss: 0.2455 - accuracy: 0.9147 - val_loss: 0.2849 - val_accuracy: 0.9125
# Epoch 79/98
# 46/46 [==============================] - 28s 612ms/step - loss: 0.2846 - accuracy: 0.9072 - val_loss: 0.3020 - val_accuracy: 0.9000
# Epoch 80/98
# 46/46 [==============================] - 26s 556ms/step - loss: 0.2506 - accuracy: 0.9141 - val_loss: 0.4528 - val_accuracy: 0.8375
# Epoch 81/98
# 46/46 [==============================] - 26s 564ms/step - loss: 0.2365 - accuracy: 0.9141 - val_loss: 0.2637 - val_accuracy: 0.9062
# Epoch 82/98
# 46/46 [==============================] - 30s 664ms/step - loss: 0.2501 - accuracy: 0.9154 - val_loss: 0.2756 - val_accuracy: 0.8875
# Epoch 83/98
# 46/46 [==============================] - 30s 658ms/step - loss: 0.2235 - accuracy: 0.9188 - val_loss: 0.4059 - val_accuracy: 0.8500
# Epoch 84/98
# 46/46 [==============================] - 26s 568ms/step - loss: 0.2359 - accuracy: 0.9188 - val_loss: 0.2499 - val_accuracy: 0.9250
# Epoch 85/98
# 46/46 [==============================] - 27s 583ms/step - loss: 0.2388 - accuracy: 0.9202 - val_loss: 0.2788 - val_accuracy: 0.8813
# Epoch 86/98
# 46/46 [==============================] - 26s 567ms/step - loss: 0.2380 - accuracy: 0.9202 - val_loss: 0.3532 - val_accuracy: 0.8750
# Epoch 87/98
# 46/46 [==============================] - 26s 561ms/step - loss: 0.2394 - accuracy: 0.9120 - val_loss: 0.3135 - val_accuracy: 0.8813
# Epoch 88/98
# 46/46 [==============================] - 26s 564ms/step - loss: 0.2381 - accuracy: 0.9175 - val_loss: 0.2656 - val_accuracy: 0.8938
# Epoch 89/98
# 46/46 [==============================] - 26s 570ms/step - loss: 0.2377 - accuracy: 0.9147 - val_loss: 0.3614 - val_accuracy: 0.8750
# Epoch 90/98
# 46/46 [==============================] - 26s 578ms/step - loss: 0.2374 - accuracy: 0.9202 - val_loss: 0.3540 - val_accuracy: 0.8687
# Epoch 91/98
# 46/46 [==============================] - 26s 569ms/step - loss: 0.2374 - accuracy: 0.9175 - val_loss: 0.2584 - val_accuracy: 0.9062
# Epoch 92/98
# 46/46 [==============================] - 26s 574ms/step - loss: 0.2363 - accuracy: 0.9147 - val_loss: 0.2990 - val_accuracy: 0.8750
# Epoch 93/98
# 46/46 [==============================] - 26s 564ms/step - loss: 0.2005 - accuracy: 0.9284 - val_loss: 0.2729 - val_accuracy: 0.8938
# Epoch 94/98
# 46/46 [==============================] - 26s 570ms/step - loss: 0.2116 - accuracy: 0.9318 - val_loss: 0.3182 - val_accuracy: 0.8687
# Epoch 95/98
# 46/46 [==============================] - 26s 561ms/step - loss: 0.2497 - accuracy: 0.9093 - val_loss: 0.3144 - val_accuracy: 0.8813
# Epoch 96/98
# 46/46 [==============================] - 26s 569ms/step - loss: 0.2199 - accuracy: 0.9236 - val_loss: 0.2894 - val_accuracy: 0.8875
# Epoch 97/98
# 46/46 [==============================] - 26s 571ms/step - loss: 0.2018 - accuracy: 0.9332 - val_loss: 0.2667 - val_accuracy: 0.8938
# Epoch 98/98
# 46/46 [==============================] - 26s 558ms/step - loss: 0.2368 - accuracy: 0.9175 - val_loss: 0.2788 - val_accuracy: 0.9062

# %%
scores = DenseNet201_model.evaluate(test_ds)
print(f"Test Accuracy: {round(scores[1],4)*100}%")
# Out:
# 7/7 [==============================] - 8s 170ms/step - loss: 0.2844 - accuracy: 0.8929
# Test Accuracy: 89.29%

# %% [markdown]
# Plotting the Accuracy and Loss Curves

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
EPOCHS = len(acc)

plt.figure(figsize=(8, 5))
plt.subplot(1, 2, 1)
plt.plot(range(EPOCHS), acc, label='Training Accuracy', color='blue')
plt.plot(range(EPOCHS), val_acc, label='Validation Accuracy', color='orange')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.grid(True)
plt.show()

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']
EPOCHS = len(loss)  # Assuming loss and val_loss have the same length
plt.figure(figsize=(8, 5))
plt.subplot(1, 2, 2)
plt.plot(range(EPOCHS), loss, label='Training Loss', color='blue')
plt.plot(range(EPOCHS), val_loss, label='Validation Loss', color='orange')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.show()

# %%
# Make predictions using the model
predictions = DenseNet201_model.predict(test_ds)
# Get the predicted class labels
predicted_labels = [np.argmax(prediction) for prediction in predictions]
test_labels = []
for images, labels in test_ds:
    test_labels.extend(labels.numpy())
test_labels = np.array(test_labels)
confusion = confusion_matrix(test_labels, predicted_labels)

print("Confusion Matrix:")
print(confusion)
# Out:
# 7/7 [==============================] - 1s 171ms/step
# Confusion Matrix:
# [[11  4  1  3  8  2]
#  [ 5 17  5  9  7  1]
#  [ 1  3 20  3  9  2]
#  [ 2  2  2 20  4  4]
#  [ 3  6  7  7 24  3]
#  [ 0  2  3  3  2 19]]

# %%
def plot_confusion_matrix(confusion_matrix, class_names):
    plt.figure(figsize=(5, 4))
    sns.heatmap(confusion_matrix, annot=True, fmt='d', cmap='Oranges', xticklabels=class_names, yticklabels=class_names)
    plt.xlabel('Predicted')
    plt.ylabel('Actual')
    plt.title('Confusion Matrix')
    plt.show()

# Call the function to display the confusion matrix
plot_confusion_matrix(confusion, class_names)

# %%
from sklearn.metrics import classification_report
test_labels = []  # True labels
predicted_labels = []  # Predicted labels

for images_batch, labels_batch in test_ds:
    batch_prediction = DenseNet201_model.predict(images_batch)
    predicted_labels.extend(np.argmax(batch_prediction, axis=1))
    test_labels.extend(labels_batch.numpy())
report = classification_report(test_labels, predicted_labels, target_names=class_names)
print(report)
# Out:
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 48ms/step
#                        precision    recall  f1-score   support
#
# Bacterial_leaf_blight       0.95      0.72      0.82        29
#            Brown_spot       0.94      0.73      0.82        44
#          Healthy_leaf       0.95      0.95      0.95        38
#            Leaf_Blast       0.73      0.97      0.84        34
#                 Other       0.93      1.00      0.96        50
#                Tungro       0.90      0.97      0.93        29
#
#              accuracy                           0.89       224
#             macro avg       0.90      0.89      0.89       224
#          weighted avg       0.90      0.89      0.89       224

# %% [markdown]
# Run prediction on a sample image

# %%
for images_batch, labels_batch in test_ds.take(1):

    first_image = images_batch[0].numpy().astype('uint8')
    first_label = labels_batch[0].numpy()

    print("first image to predict")
    plt.imshow(first_image)
    print("actual label:",class_names[first_label])

    batch_prediction = DenseNet201_model.predict(images_batch)
    print("predicted label:",class_names[np.argmax(batch_prediction[0])])
# Out:
# first image to predict
# actual label: Healthy_leaf
# 1/1 [==============================] - 0s 56ms/step
# predicted label: Healthy_leaf
