# %%
pip install seaborn matplotlib
# Out:
# Requirement already satisfied: seaborn in /usr/local/lib/python3.10/dist-packages (0.13.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.7.1)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /usr/local/lib/python3.10/dist-packages (from seaborn) (1.25.2)
# Requirement already satisfied: pandas>=1.2 in /usr/local/lib/python3.10/dist-packages (from seaborn) (1.5.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.49.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.2->seaborn) (2023.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
import keras
import pandas as pd
import numpy as np
import itertools
import seaborn as sns
from sklearn import svm
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.metrics import f1_score
from sklearn.metrics import auc
from keras.models import Sequential
from tensorflow.keras import models, layers
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.utils import plot_model
from sklearn.metrics import roc_curve, roc_auc_score
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import average_precision_score
from keras. layers import Activation, Dropout, Flatten, Dense
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from sklearn.model_selection import train_test_split, cross_val_score
from keras.layers import Conv1D, MaxPooling2D, MaxPooling1D, BatchNormalization
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
import warnings
warnings.filterwarnings('ignore')
def ignore_warn(*args, **kwargs):
  pass
  warnings.warn=ignore_warn

# %%
BATCH_SIZE = 32
IMAGE_SIZE = 300
CHANNELS=3
EPOCHS=98

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
dataset = tf.keras.preprocessing.image_dataset_from_directory(
    "/content/drive/MyDrive/Paddy Leaf Disease Detection/Final_Dataset(RLDD)",
    seed=123,
    shuffle=True,
    image_size=(IMAGE_SIZE,IMAGE_SIZE),
    batch_size=BATCH_SIZE
)
# Out:
# Found 1850 files belonging to 6 classes.

# %%
class_names = dataset.class_names
class_names
# Out:
# ['Bacterial_leaf_blight',
#  'Brown_spot',
#  'Healthy_leaf',
#  'Leaf_Blast',
#  'Other',
#  'Tungro']

# %%
for image_batch, labels_batch in dataset.take(1):
    print(image_batch.shape)
    print(labels_batch.numpy())
# Out:
# (32, 300, 300, 3)
# [5 4 0 3 2 2 1 3 2 5 0 4 4 1 4 4 3 2 2 4 3 5 2 3 1 1 2 2 1 2 4 2]

# %%
len(dataset)
# Out:
# 58

# %%
new_image_size = (256, 256)
resized_dataset = dataset.map(lambda x, y: (tf.image.resize(x, new_image_size), y))
for image_batch, labels_batch in resized_dataset.take(1):
    print(image_batch.shape)
# Out:
# (32, 256, 256, 3)

# %%
import random
# Assuming you have a list of colors corresponding to each class
class_colors = [f'#{random.randint(0, 0xFFFFFF):06x}' for _ in class_names]

class_counts = [0] * len(class_names)
for images_batch, labels_batch in resized_dataset:# resized_dataset
    for label in labels_batch:
        class_counts[label] += 1

plt.figure(figsize=(6, 6))
patches, texts, autotexts = plt.pie(class_counts,
                                   autopct='%1.1f%%', startangle=140, colors=class_colors)

plt.legend(patches, class_names, loc='center left', bbox_to_anchor=(1, 0.5))

plt.title("Class Label Distribution")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Create a list to store the count of each class label
class_counts = [0] * len(class_names)
for images_batch, labels_batch in resized_dataset:
    for label in labels_batch:
        class_counts[label] += 1

# Plotting the bar chart
plt.figure(figsize=(10, 6))
plt.bar(class_names, class_counts, color='skyblue')
plt.title("Class Label Distribution")
plt.xlabel("Class Labels")
plt.ylabel("Count")
plt.xticks(rotation=45, ha="right")
plt.show()

# %% [markdown]
# **Visualize some of the images from our datasetmodel**

# %%
plt.figure(figsize=(10, 10))
for image_batch, label_batch in resized_dataset.take(1):
  for i in range(12):
    ax = plt.subplot(3,4,i+1)
    plt.imshow(image_batch[i].numpy().astype("uint8"))
    plt.title(class_names[label_batch[i]])
    plt.axis("off")
  #print(image_batch[0].shape)

# %% [markdown]
# Function to Split Dataset Dataset should be bifurcated into 3 subsets, namely:
#
# Training: Dataset to be used while training Validation: Dataset to be tested against while training Test: Dataset to be tested against after we trained a model **bold text**

# %%
train_size = 0.8
len(resized_dataset)*train_size
# Out:
# 46.400000000000006

# %%
train_ds= resized_dataset.take(46)
len(train_ds)
# Out:
# 46

# %%
test_ds = resized_dataset.skip(46)
len(test_ds)
# Out:
# 12

# %%
val_size = 0.1
len(resized_dataset)*val_size
# Out:
# 5.800000000000001

# %%
val_ds = test_ds.take(6)
len(val_ds)
# Out:
# 6

# %%
test_ds = test_ds.skip(6)
len(test_ds)
# Out:
# 6

# %%
def get_dataset_partitions_tf(ds, train_split=0.8, val_split=0.1, test_split=0.1, shuffle=True, shuffle_size=10000):
    assert (train_split + test_split + val_split) == 1
    ds_size = len(ds)
    if shuffle:
      ds = ds.shuffle(shuffle_size, seed=12)
      train_size = int(train_split * ds_size)
      val_size = int(val_split * ds_size)
      train_ds = ds.take(train_size)
      val_ds = ds.skip(train_size).take(val_size)
      test_ds = ds.skip(train_size).skip(val_size)
      return train_ds, val_ds, test_ds

# %%
train_ds, val_ds, test_ds = get_dataset_partitions_tf(resized_dataset)

# %% [markdown]
# **Cache, Shuffle, and Prefetch the Dataset**

# %%
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)
val_ds = val_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)
test_ds = test_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)

# %%
resize_and_rescale = tf.keras.Sequential([
  layers.experimental.preprocessing.Resizing(256, 256),
  layers.experimental.preprocessing.Rescaling(1./255),
])

# %% [markdown]
# **Data Augmentation Data Augmentation is needed when we have less data, this boosts the accuracy of our model by augmenting the data**

# %%
data_augmentation = tf.keras.Sequential([
  layers.experimental.preprocessing.RandomFlip("horizontal_and_vertical",dtype=tf.float32),  # Explicitly set data type
    # ... other preprocessing layers
  layers.experimental.preprocessing.RandomRotation(0.2),
  layers.experimental.preprocessing.RandomZoom(0.1),
  layers.experimental.preprocessing.RandomContrast(0.2),
])

# %% [markdown]
# **Applying Data Augmentation to Train Dataset**

# %%
train_ds = train_ds.map(
    lambda x, y: (data_augmentation(x, training=True), y)
).prefetch(buffer_size=tf.data.AUTOTUNE)

# %%
IMAGE_SIZE = (256, 256)
BATCH_SIZE = 32
SEQUENCE_LENGTH = 10  # Number of frames per sequence
NUM_CLASSES = 6

# Load the ResNet50 model
resnet_model = ResNet50(weights='imagenet', include_top=False, input_shape=(IMAGE_SIZE[0], IMAGE_SIZE[1], 3))
for layer in resnet_model.layers:
    layer.trainable = False

# Define the LSTM model
lstm_model = models.Sequential([
    layers.LSTM(64, return_sequences=True),
    layers.LSTM(64),
])
# Combine the ResNet and LSTM models
combined_model = models.Sequential([
    resnet_model,
    layers.TimeDistributed(layers.Flatten()),
    lstm_model,
    layers.Dense(NUM_CLASSES, activation='softmax')
])
combined_model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)
combined_model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 [==============================] - 3s 0us/step
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet50 (Functional)       (None, 8, 8, 2048)        23587712
#
#  time_distributed (TimeDist  (None, 8, 16384)          0
#  ributed)
#
#  sequential_2 (Sequential)   (None, 64)                4243968
#
#  dense (Dense)               (None, 6)                 390
#
# =================================================================
# Total params: 27832070 (106.17 MB)
# Trainable params: 4244358 (16.19 MB)
# Non-trainable params: 23587712 (89.98 MB)
# _________________________________________________________________

# %%
plot_model(combined_model, to_file='resnet_lstm.png', show_shapes=True)

# %%
history = combined_model.fit(
    train_ds,
    batch_size=BATCH_SIZE,
    validation_data=val_ds,
    verbose=1,
    epochs=EPOCHS,
)
# Out:
# Epoch 1/98
# 46/46 [==============================] - 53s 750ms/step - loss: 0.7046 - accuracy: 0.7804 - val_loss: 0.3126 - val_accuracy: 0.9062
# Epoch 2/98
# 46/46 [==============================] - 26s 556ms/step - loss: 0.2952 - accuracy: 0.9031 - val_loss: 0.3644 - val_accuracy: 0.8562
# Epoch 3/98
# 46/46 [==============================] - 25s 544ms/step - loss: 0.2729 - accuracy: 0.9141 - val_loss: 0.1699 - val_accuracy: 0.9625
# Epoch 4/98
# 46/46 [==============================] - 25s 536ms/step - loss: 0.2123 - accuracy: 0.9270 - val_loss: 0.2588 - val_accuracy: 0.9187
# Epoch 5/98
# 46/46 [==============================] - 24s 528ms/step - loss: 0.2147 - accuracy: 0.9297 - val_loss: 0.1441 - val_accuracy: 0.9438
# Epoch 6/98
# 46/46 [==============================] - 25s 540ms/step - loss: 0.1892 - accuracy: 0.9318 - val_loss: 0.2189 - val_accuracy: 0.9312
# Epoch 7/98
# 46/46 [==============================] - 26s 554ms/step - loss: 0.1986 - accuracy: 0.9297 - val_loss: 0.1632 - val_accuracy: 0.9375
# Epoch 8/98
# 46/46 [==============================] - 24s 515ms/step - loss: 0.1795 - accuracy: 0.9359 - val_loss: 0.1340 - val_accuracy: 0.9688
# Epoch 9/98
# 46/46 [==============================] - 25s 534ms/step - loss: 0.1797 - accuracy: 0.9413 - val_loss: 0.1268 - val_accuracy: 0.9563
# Epoch 10/98
# 46/46 [==============================] - 25s 540ms/step - loss: 0.1581 - accuracy: 0.9434 - val_loss: 0.1063 - val_accuracy: 0.9625
# Epoch 11/98
# 46/46 [==============================] - 23s 510ms/step - loss: 0.1397 - accuracy: 0.9516 - val_loss: 0.1505 - val_accuracy: 0.9500
# Epoch 12/98
# 46/46 [==============================] - 24s 527ms/step - loss: 0.1471 - accuracy: 0.9502 - val_loss: 0.1243 - val_accuracy: 0.9563
# Epoch 13/98
# 46/46 [==============================] - 28s 606ms/step - loss: 0.1668 - accuracy: 0.9441 - val_loss: 0.1702 - val_accuracy: 0.9250
# Epoch 14/98
# 46/46 [==============================] - 29s 640ms/step - loss: 0.1575 - accuracy: 0.9495 - val_loss: 0.1552 - val_accuracy: 0.9500
# Epoch 15/98
# 46/46 [==============================] - 25s 533ms/step - loss: 0.1624 - accuracy: 0.9447 - val_loss: 0.1230 - val_accuracy: 0.9625
# Epoch 16/98
# 46/46 [==============================] - 28s 609ms/step - loss: 0.1404 - accuracy: 0.9529 - val_loss: 0.1227 - val_accuracy: 0.9563
# Epoch 17/98
# 46/46 [==============================] - 29s 620ms/step - loss: 0.1295 - accuracy: 0.9598 - val_loss: 0.1649 - val_accuracy: 0.9438
# Epoch 18/98
# 46/46 [==============================] - 25s 539ms/step - loss: 0.1480 - accuracy: 0.9495 - val_loss: 0.1040 - val_accuracy: 0.9563
# Epoch 19/98
# 46/46 [==============================] - 27s 580ms/step - loss: 0.1405 - accuracy: 0.9488 - val_loss: 0.1156 - val_accuracy: 0.9563
# Epoch 20/98
# 46/46 [==============================] - 26s 555ms/step - loss: 0.1154 - accuracy: 0.9598 - val_loss: 0.0741 - val_accuracy: 0.9750
# Epoch 21/98
# 46/46 [==============================] - 25s 533ms/step - loss: 0.1034 - accuracy: 0.9666 - val_loss: 0.2282 - val_accuracy: 0.9187
# Epoch 22/98
# 46/46 [==============================] - 25s 540ms/step - loss: 0.1300 - accuracy: 0.9516 - val_loss: 0.0933 - val_accuracy: 0.9750
# Epoch 23/98
# 46/46 [==============================] - 25s 547ms/step - loss: 0.1110 - accuracy: 0.9550 - val_loss: 0.1005 - val_accuracy: 0.9688
# Epoch 24/98
# 46/46 [==============================] - 24s 528ms/step - loss: 0.1013 - accuracy: 0.9598 - val_loss: 0.1403 - val_accuracy: 0.9500
# Epoch 25/98
# 46/46 [==============================] - 25s 534ms/step - loss: 0.1125 - accuracy: 0.9625 - val_loss: 0.1068 - val_accuracy: 0.9625
# Epoch 26/98
# 46/46 [==============================] - 24s 528ms/step - loss: 0.1152 - accuracy: 0.9591 - val_loss: 0.1052 - val_accuracy: 0.9688
# Epoch 27/98
# 46/46 [==============================] - 24s 530ms/step - loss: 0.1301 - accuracy: 0.9516 - val_loss: 0.1057 - val_accuracy: 0.9625
# Epoch 28/98
# 46/46 [==============================] - 24s 530ms/step - loss: 0.0940 - accuracy: 0.9679 - val_loss: 0.1337 - val_accuracy: 0.9438
# Epoch 29/98
# 46/46 [==============================] - 24s 528ms/step - loss: 0.0978 - accuracy: 0.9693 - val_loss: 0.0978 - val_accuracy: 0.9625
# Epoch 30/98
# 46/46 [==============================] - 24s 520ms/step - loss: 0.1062 - accuracy: 0.9618 - val_loss: 0.1334 - val_accuracy: 0.9563
# Epoch 31/98
# 46/46 [==============================] - 25s 533ms/step - loss: 0.0991 - accuracy: 0.9659 - val_loss: 0.1271 - val_accuracy: 0.9625
# Epoch 32/98
# 46/46 [==============================] - 25s 541ms/step - loss: 0.1218 - accuracy: 0.9577 - val_loss: 0.1457 - val_accuracy: 0.9625
# Epoch 33/98
# 46/46 [==============================] - 25s 540ms/step - loss: 0.1161 - accuracy: 0.9577 - val_loss: 0.1041 - val_accuracy: 0.9688
# Epoch 34/98
# 46/46 [==============================] - 24s 529ms/step - loss: 0.0965 - accuracy: 0.9638 - val_loss: 0.0923 - val_accuracy: 0.9625
# Epoch 35/98
# 46/46 [==============================] - 25s 533ms/step - loss: 0.1031 - accuracy: 0.9618 - val_loss: 0.1522 - val_accuracy: 0.9625
# Epoch 36/98
# 46/46 [==============================] - 25s 543ms/step - loss: 0.1096 - accuracy: 0.9577 - val_loss: 0.1337 - val_accuracy: 0.9312
# Epoch 37/98
# 46/46 [==============================] - 27s 584ms/step - loss: 0.0945 - accuracy: 0.9700 - val_loss: 0.1268 - val_accuracy: 0.9625
# Epoch 38/98
# 46/46 [==============================] - 24s 528ms/step - loss: 0.0907 - accuracy: 0.9673 - val_loss: 0.1384 - val_accuracy: 0.9500
# Epoch 39/98
# 46/46 [==============================] - 24s 525ms/step - loss: 0.0815 - accuracy: 0.9714 - val_loss: 0.1281 - val_accuracy: 0.9625
# Epoch 40/98
# 46/46 [==============================] - 24s 517ms/step - loss: 0.0879 - accuracy: 0.9720 - val_loss: 0.1609 - val_accuracy: 0.9500
# Epoch 41/98
# 46/46 [==============================] - 36s 777ms/step - loss: 0.0973 - accuracy: 0.9693 - val_loss: 0.1423 - val_accuracy: 0.9500
# Epoch 42/98
# 46/46 [==============================] - 25s 533ms/step - loss: 0.0840 - accuracy: 0.9714 - val_loss: 0.1117 - val_accuracy: 0.9563
# Epoch 43/98
# 46/46 [==============================] - 24s 526ms/step - loss: 0.0924 - accuracy: 0.9659 - val_loss: 0.0868 - val_accuracy: 0.9688
# Epoch 44/98
# 46/46 [==============================] - 25s 533ms/step - loss: 0.1060 - accuracy: 0.9632 - val_loss: 0.0549 - val_accuracy: 0.9812
# Epoch 45/98
# 46/46 [==============================] - 25s 544ms/step - loss: 0.0812 - accuracy: 0.9700 - val_loss: 0.1225 - val_accuracy: 0.9500
# Epoch 46/98
# 46/46 [==============================] - 26s 558ms/step - loss: 0.0860 - accuracy: 0.9679 - val_loss: 0.0970 - val_accuracy: 0.9750
# Epoch 47/98
# 46/46 [==============================] - 24s 528ms/step - loss: 0.0810 - accuracy: 0.9679 - val_loss: 0.1683 - val_accuracy: 0.9438
# Epoch 48/98
# 46/46 [==============================] - 24s 526ms/step - loss: 0.0792 - accuracy: 0.9741 - val_loss: 0.0855 - val_accuracy: 0.9625
# Epoch 49/98
# 46/46 [==============================] - 24s 528ms/step - loss: 0.0912 - accuracy: 0.9666 - val_loss: 0.1056 - val_accuracy: 0.9688
# Epoch 50/98
# 46/46 [==============================] - 24s 525ms/step - loss: 0.0865 - accuracy: 0.9714 - val_loss: 0.1412 - val_accuracy: 0.9500
# Epoch 51/98
# 46/46 [==============================] - 24s 528ms/step - loss: 0.0738 - accuracy: 0.9714 - val_loss: 0.1189 - val_accuracy: 0.9625
# Epoch 52/98
# 46/46 [==============================] - 25s 530ms/step - loss: 0.1114 - accuracy: 0.9618 - val_loss: 0.1166 - val_accuracy: 0.9688
# Epoch 53/98
# 46/46 [==============================] - 25s 535ms/step - loss: 0.0844 - accuracy: 0.9686 - val_loss: 0.1096 - val_accuracy: 0.9688
# Epoch 54/98
# 46/46 [==============================] - 25s 544ms/step - loss: 0.0818 - accuracy: 0.9720 - val_loss: 0.1332 - val_accuracy: 0.9625
# Epoch 55/98
# 46/46 [==============================] - 26s 558ms/step - loss: 0.0638 - accuracy: 0.9789 - val_loss: 0.0814 - val_accuracy: 0.9812
# Epoch 56/98
# 46/46 [==============================] - 25s 547ms/step - loss: 0.0904 - accuracy: 0.9679 - val_loss: 0.1470 - val_accuracy: 0.9438
# Epoch 57/98
# 46/46 [==============================] - 24s 523ms/step - loss: 0.0673 - accuracy: 0.9768 - val_loss: 0.1050 - val_accuracy: 0.9750
# Epoch 58/98
# 46/46 [==============================] - 25s 540ms/step - loss: 0.0615 - accuracy: 0.9802 - val_loss: 0.1576 - val_accuracy: 0.9563
# Epoch 59/98
# 46/46 [==============================] - 25s 546ms/step - loss: 0.0763 - accuracy: 0.9707 - val_loss: 0.0875 - val_accuracy: 0.9688
# Epoch 60/98
# 46/46 [==============================] - 24s 527ms/step - loss: 0.0747 - accuracy: 0.9734 - val_loss: 0.0866 - val_accuracy: 0.9625
# Epoch 61/98
# 46/46 [==============================] - 24s 531ms/step - loss: 0.0677 - accuracy: 0.9775 - val_loss: 0.0715 - val_accuracy: 0.9688
# Epoch 62/98
# 46/46 [==============================] - 25s 534ms/step - loss: 0.0692 - accuracy: 0.9789 - val_loss: 0.0428 - val_accuracy: 0.9875
# Epoch 63/98
# 46/46 [==============================] - 24s 523ms/step - loss: 0.0635 - accuracy: 0.9829 - val_loss: 0.0404 - val_accuracy: 0.9875
# Epoch 64/98
# 46/46 [==============================] - 25s 532ms/step - loss: 0.0702 - accuracy: 0.9741 - val_loss: 0.0871 - val_accuracy: 0.9625
# Epoch 65/98
# 46/46 [==============================] - 25s 534ms/step - loss: 0.0656 - accuracy: 0.9754 - val_loss: 0.0726 - val_accuracy: 0.9812
# Epoch 66/98
# 46/46 [==============================] - 24s 530ms/step - loss: 0.0699 - accuracy: 0.9727 - val_loss: 0.0965 - val_accuracy: 0.9688
# Epoch 67/98
# 46/46 [==============================] - 24s 521ms/step - loss: 0.0767 - accuracy: 0.9707 - val_loss: 0.0789 - val_accuracy: 0.9688
# Epoch 68/98
# 46/46 [==============================] - 25s 545ms/step - loss: 0.0564 - accuracy: 0.9823 - val_loss: 0.0801 - val_accuracy: 0.9750
# Epoch 69/98
# 46/46 [==============================] - 25s 549ms/step - loss: 0.0622 - accuracy: 0.9795 - val_loss: 0.0835 - val_accuracy: 0.9625
# Epoch 70/98
# 46/46 [==============================] - 24s 531ms/step - loss: 0.0556 - accuracy: 0.9795 - val_loss: 0.0841 - val_accuracy: 0.9625
# Epoch 71/98
# 46/46 [==============================] - 25s 536ms/step - loss: 0.0680 - accuracy: 0.9768 - val_loss: 0.1113 - val_accuracy: 0.9688
# Epoch 72/98
# 46/46 [==============================] - 25s 547ms/step - loss: 0.0562 - accuracy: 0.9789 - val_loss: 0.0701 - val_accuracy: 0.9750
# Epoch 73/98
# 46/46 [==============================] - 24s 528ms/step - loss: 0.0608 - accuracy: 0.9823 - val_loss: 0.1021 - val_accuracy: 0.9563
# Epoch 74/98
# 46/46 [==============================] - 25s 529ms/step - loss: 0.0531 - accuracy: 0.9809 - val_loss: 0.1013 - val_accuracy: 0.9625
# Epoch 75/98
# 46/46 [==============================] - 24s 522ms/step - loss: 0.0598 - accuracy: 0.9809 - val_loss: 0.0580 - val_accuracy: 0.9875
# Epoch 76/98
# 46/46 [==============================] - 24s 522ms/step - loss: 0.0705 - accuracy: 0.9768 - val_loss: 0.0522 - val_accuracy: 0.9875
# Epoch 77/98
# 46/46 [==============================] - 25s 549ms/step - loss: 0.0674 - accuracy: 0.9809 - val_loss: 0.0444 - val_accuracy: 0.9937
# Epoch 78/98
# 46/46 [==============================] - 25s 551ms/step - loss: 0.0593 - accuracy: 0.9809 - val_loss: 0.0583 - val_accuracy: 0.9812
# Epoch 79/98
# 46/46 [==============================] - 25s 538ms/step - loss: 0.0578 - accuracy: 0.9802 - val_loss: 0.1030 - val_accuracy: 0.9750
# Epoch 80/98
# 46/46 [==============================] - 25s 537ms/step - loss: 0.0588 - accuracy: 0.9795 - val_loss: 0.0523 - val_accuracy: 0.9875
# Epoch 81/98
# 46/46 [==============================] - 25s 547ms/step - loss: 0.0600 - accuracy: 0.9802 - val_loss: 0.0391 - val_accuracy: 0.9937
# Epoch 82/98
# 46/46 [==============================] - 26s 555ms/step - loss: 0.0710 - accuracy: 0.9761 - val_loss: 0.0612 - val_accuracy: 0.9750
# Epoch 83/98
# 46/46 [==============================] - 25s 537ms/step - loss: 0.0609 - accuracy: 0.9789 - val_loss: 0.0491 - val_accuracy: 0.9875
# Epoch 84/98
# 46/46 [==============================] - 25s 531ms/step - loss: 0.0679 - accuracy: 0.9734 - val_loss: 0.0848 - val_accuracy: 0.9688
# Epoch 85/98
# 46/46 [==============================] - 25s 545ms/step - loss: 0.0561 - accuracy: 0.9789 - val_loss: 0.0328 - val_accuracy: 0.9875
# Epoch 86/98
# 46/46 [==============================] - 25s 536ms/step - loss: 0.0729 - accuracy: 0.9741 - val_loss: 0.0496 - val_accuracy: 0.9750
# Epoch 87/98
# 46/46 [==============================] - 24s 526ms/step - loss: 0.0630 - accuracy: 0.9782 - val_loss: 0.0284 - val_accuracy: 0.9875
# Epoch 88/98
# 46/46 [==============================] - 25s 543ms/step - loss: 0.0497 - accuracy: 0.9843 - val_loss: 0.0742 - val_accuracy: 0.9688
# Epoch 89/98
# 46/46 [==============================] - 24s 529ms/step - loss: 0.0526 - accuracy: 0.9809 - val_loss: 0.0416 - val_accuracy: 0.9875
# Epoch 90/98
# 46/46 [==============================] - 25s 545ms/step - loss: 0.0568 - accuracy: 0.9802 - val_loss: 0.0428 - val_accuracy: 0.9875
# Epoch 91/98
# 46/46 [==============================] - 25s 550ms/step - loss: 0.0474 - accuracy: 0.9829 - val_loss: 0.0387 - val_accuracy: 0.9937
# Epoch 92/98
# 46/46 [==============================] - 26s 566ms/step - loss: 0.0581 - accuracy: 0.9782 - val_loss: 0.0523 - val_accuracy: 0.9688
# Epoch 93/98
# 46/46 [==============================] - 25s 541ms/step - loss: 0.0520 - accuracy: 0.9789 - val_loss: 0.0704 - val_accuracy: 0.9750
# Epoch 94/98
# 46/46 [==============================] - 25s 547ms/step - loss: 0.0492 - accuracy: 0.9789 - val_loss: 0.0354 - val_accuracy: 0.9750
# Epoch 95/98
# 46/46 [==============================] - 26s 556ms/step - loss: 0.0482 - accuracy: 0.9850 - val_loss: 0.0321 - val_accuracy: 0.9812
# Epoch 96/98
# 46/46 [==============================] - 25s 537ms/step - loss: 0.0564 - accuracy: 0.9802 - val_loss: 0.0504 - val_accuracy: 0.9812
# Epoch 97/98
# 46/46 [==============================] - 25s 537ms/step - loss: 0.0792 - accuracy: 0.9727 - val_loss: 0.0507 - val_accuracy: 0.9750
# Epoch 98/98
# 46/46 [==============================] - 25s 549ms/step - loss: 0.0558 - accuracy: 0.9789 - val_loss: 0.0421 - val_accuracy: 0.9812

# %%
scores = combined_model.evaluate(test_ds)
print(f"Test Accuracy: {round(scores[1],4)*100}%")
# Out:
# 7/7 [==============================] - 7s 125ms/step - loss: 0.0425 - accuracy: 0.9866
# Test Accuracy: 98.66%

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
EPOCHS = len(acc)

plt.figure(figsize=(8, 5))
plt.subplot(1, 2, 1)
plt.plot(range(EPOCHS), acc, label='Training Accuracy', color='blue')
plt.plot(range(EPOCHS), val_acc, label='Validation Accuracy', color='orange')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.grid(True)
plt.show()

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']
EPOCHS = len(loss)  # Assuming loss and val_loss have the same length
plt.figure(figsize=(8, 5))
plt.subplot(1, 2, 2)
plt.plot(range(EPOCHS), loss, label='Training Loss', color='blue')
plt.plot(range(EPOCHS), val_loss, label='Validation Loss', color='orange')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.grid(True)
plt.show()

# %%
# Make predictions using the model
predictions = combined_model.predict(test_ds)
# Get the predicted class labels
predicted_labels = [np.argmax(prediction) for prediction in predictions]
test_labels = []
for images, labels in test_ds:
    test_labels.extend(labels.numpy())
test_labels = np.array(test_labels)
confusion = confusion_matrix(test_labels, predicted_labels)

print("Confusion Matrix:")
print(confusion)
# Out:
# 7/7 [==============================] - 2s 101ms/step
# Confusion Matrix:
# [[17  4  9  3  2  3]
#  [ 5 19  3  1  8  1]
#  [ 8  5 27  7  1  6]
#  [ 0  4  8 11  2  3]
#  [ 3  3  5  1 18  6]
#  [ 3  4  2  4  5 13]]

# %%
def plot_confusion_matrix(confusion_matrix, class_names):
    plt.figure(figsize=(5, 4))
    sns.heatmap(confusion_matrix, annot=True, fmt='d', cmap='PuBu', xticklabels=class_names, yticklabels=class_names)
    plt.xlabel('Predicted')
    plt.ylabel('Actual')
    plt.title('Confusion Matrix')
    plt.show()

plot_confusion_matrix(confusion, class_names)

# %%
from sklearn.metrics import classification_report
test_labels = []  # True labels
predicted_labels = []  # Predicted labels

for images_batch, labels_batch in test_ds:
    batch_prediction = combined_model.predict(images_batch)
    predicted_labels.extend(np.argmax(batch_prediction, axis=1))
    test_labels.extend(labels_batch.numpy())
report = classification_report(test_labels, predicted_labels, target_names=class_names)
print(report)
# Out:
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
#                        precision    recall  f1-score   support
#
# Bacterial_leaf_blight       1.00      0.95      0.97        38
#            Brown_spot       0.95      1.00      0.97        37
#          Healthy_leaf       1.00      1.00      1.00        54
#            Leaf_Blast       1.00      0.96      0.98        28
#                 Other       1.00      1.00      1.00        36
#                Tungro       0.97      1.00      0.98        31
#
#              accuracy                           0.99       224
#             macro avg       0.99      0.99      0.99       224
#          weighted avg       0.99      0.99      0.99       224

# %%
for images_batch, labels_batch in test_ds.take(1):
    first_image = images_batch[0].numpy().astype('uint8')
    first_label = labels_batch[0].numpy()
    print("first image to predict")
    plt.imshow(first_image)
    print("actual label:",class_names[first_label])
    batch_prediction = combined_model.predict(images_batch)
    print("predicted label:",class_names[np.argmax(batch_prediction[0])])
# Out:
# first image to predict
# actual label: Brown_spot
# 1/1 [==============================] - 0s 49ms/step
# predicted label: Brown_spot
