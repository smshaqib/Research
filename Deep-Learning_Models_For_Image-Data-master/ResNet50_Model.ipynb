# %%
pip install seaborn matplotlib
# Out:
# Requirement already satisfied: seaborn in /usr/local/lib/python3.10/dist-packages (0.13.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.7.1)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /usr/local/lib/python3.10/dist-packages (from seaborn) (1.25.2)
# Requirement already satisfied: pandas>=1.2 in /usr/local/lib/python3.10/dist-packages (from seaborn) (1.5.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.49.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.2->seaborn) (2023.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
import keras
import pandas as pd
import numpy as np
import itertools
import seaborn as sns
from sklearn import svm
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.metrics import f1_score
from sklearn.metrics import auc
from keras.models import Sequential
from tensorflow.keras import models, layers
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.utils import plot_model
from sklearn.metrics import roc_curve, roc_auc_score
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import average_precision_score
from keras. layers import Activation, Dropout, Flatten, Dense
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.applications import MobileNetV3Large
from tensorflow.keras.optimizers.schedules import ExponentialDecay
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from sklearn.model_selection import train_test_split, cross_val_score
from keras.layers import Conv1D, MaxPooling2D, MaxPooling1D, BatchNormalization
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
import warnings
warnings.filterwarnings('ignore')
def ignore_warn(*args, **kwargs):
  pass
  warnings.warn=ignore_warn

# %%
BATCH_SIZE = 32
IMAGE_SIZE = 300
CHANNELS=3
EPOCHS=98

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
dataset = tf.keras.preprocessing.image_dataset_from_directory(
    "/content/drive/MyDrive/Paddy Leaf Disease Detection/Final_Dataset(RLDD)",
    seed=123,
    shuffle=True,
    image_size=(IMAGE_SIZE,IMAGE_SIZE),
    batch_size=BATCH_SIZE
)
# Out:
# Found 1850 files belonging to 6 classes.

# %%
class_names = dataset.class_names
class_names
# Out:
# ['Bacterial_leaf_blight',
#  'Brown_spot',
#  'Healthy_leaf',
#  'Leaf_Blast',
#  'Other',
#  'Tungro']

# %%
for image_batch, labels_batch in dataset.take(1):
    print(image_batch.shape)
    print(labels_batch.numpy())
# Out:
# (32, 300, 300, 3)
# [5 4 0 3 2 2 1 3 2 5 0 4 4 1 4 4 3 2 2 4 3 5 2 3 1 1 2 2 1 2 4 2]

# %%
new_image_size = (256, 256)
resized_dataset = dataset.map(lambda x, y: (tf.image.resize(x, new_image_size), y))
for image_batch, labels_batch in resized_dataset.take(1):
    print(image_batch.shape)
# Out:
# (32, 256, 256, 3)

# %%
import random
# Assuming you have a list of colors corresponding to each class
class_colors = [f'#{random.randint(0, 0xFFFFFF):06x}' for _ in class_names]

class_counts = [0] * len(class_names)
for images_batch, labels_batch in resized_dataset:# resized_dataset
    for label in labels_batch:
        class_counts[label] += 1
plt.figure(figsize=(6, 6))
patches, texts, autotexts = plt.pie(class_counts,
                                   autopct='%1.1f%%', startangle=140, colors=class_colors)

plt.legend(patches, class_names, loc='center left', bbox_to_anchor=(1, 0.5))
plt.title("Class Label Distribution")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Create a list to store the count of each class label
class_counts = [0] * len(class_names)
for images_batch, labels_batch in resized_dataset:
    for label in labels_batch:
        class_counts[label] += 1

# Plotting the bar chart
plt.figure(figsize=(10, 6))
plt.bar(class_names, class_counts, color='skyblue')
plt.title("Class Label Distribution")
plt.xlabel("Class Labels")
plt.ylabel("Count")
plt.xticks(rotation=45, ha="right")
plt.show()

# %%
plt.figure(figsize=(10, 10))
for image_batch, label_batch in resized_dataset.take(1):
  for i in range(12):
    ax = plt.subplot(3,4,i+1)
    plt.imshow(image_batch[i].numpy().astype("uint8"))
    plt.title(class_names[label_batch[i]])
    plt.axis("off")
  print(image_batch[0].shape)
# Out:
# (256, 256, 3)

# %%
train_size = 0.8
len(resized_dataset)*train_size
# Out:
# 46.400000000000006

# %%
train_ds= resized_dataset.take(46)
len(train_ds)
# Out:
# 46

# %%
test_ds = resized_dataset.skip(46)
len(test_ds)
# Out:
# 12

# %%
val_size = 0.1
len(resized_dataset)*val_size
# Out:
# 5.800000000000001

# %%
val_ds = test_ds.take(6)
len(val_ds)
# Out:
# 6

# %%
test_ds = test_ds.skip(6)
len(test_ds)
# Out:
# 6

# %%
def get_dataset_partitions_tf(ds, train_split=0.8, val_split=0.1, test_split=0.1, shuffle=True, shuffle_size=10000):
    assert (train_split + test_split + val_split) == 1
    ds_size = len(ds)
    if shuffle:
      ds = ds.shuffle(shuffle_size, seed=12)
      train_size = int(train_split * ds_size)
      val_size = int(val_split * ds_size)
      train_ds = ds.take(train_size)
      val_ds = ds.skip(train_size).take(val_size)
      test_ds = ds.skip(train_size).skip(val_size)
      return train_ds, val_ds, test_ds

# %%
train_ds, val_ds, test_ds = get_dataset_partitions_tf(resized_dataset)

# %%
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)
val_ds = val_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)
test_ds = test_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)

# %%
resize_and_rescale = tf.keras.Sequential([
  layers.experimental.preprocessing.Resizing(256, 256),
  layers.experimental.preprocessing.Rescaling(1./255),
])

# %%
data_augmentation = tf.keras.Sequential([
  layers.experimental.preprocessing.RandomFlip("horizontal_and_vertical",dtype=tf.float32),  # Explicitly set data type
    # ... other preprocessing layers
  layers.experimental.preprocessing.RandomRotation(0.2),
  layers.experimental.preprocessing.RandomZoom(0.1),
  layers.experimental.preprocessing.RandomContrast(0.2),
])

# %%
train_ds = train_ds.map(
    lambda x, y: (data_augmentation(x, training=True), y)
).prefetch(buffer_size=tf.data.AUTOTUNE)

# %%
from tensorflow.keras.applications import ResNet50
n_classes=6
# Load the ResNet50 model
resnet_model = ResNet50(weights='imagenet', include_top=False, input_shape=(256, 256, CHANNELS))
# Freeze the ResNet layers
for layer in resnet_model.layers:
    layer.trainable = False

resnet50_model = tf.keras.Sequential([
    layers.Input(shape=(256, 256, CHANNELS)),
    data_augmentation,
    resnet_model,
    layers.GlobalAveragePooling2D(),
    layers.Dense(n_classes, activation='softmax')
])
resnet50_model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 [==============================] - 5s 0us/step
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential_1 (Sequential)   (None, 256, 256, 3)       0
#
#  resnet50 (Functional)       (None, 8, 8, 2048)        23587712
#
#  global_average_pooling2d (  (None, 2048)              0
#  GlobalAveragePooling2D)
#
#  dense (Dense)               (None, 6)                 12294
#
# =================================================================
# Total params: 23600006 (90.03 MB)
# Trainable params: 12294 (48.02 KB)
# Non-trainable params: 23587712 (89.98 MB)
# _________________________________________________________________

# %%
plot_model(resnet50_model, to_file='resnet50.png', show_shapes=True)

# %%
from tensorflow.keras.optimizers.schedules import ExponentialDecay
initial_learning_rate = 0.001
lr_schedule = ExponentialDecay(
    initial_learning_rate, decay_steps=1000, decay_rate=0.9, staircase=True
    )

# %%
resnet50_model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=lr_schedule),
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
    metrics=['accuracy']
)

# %%
history = resnet50_model.fit(
    train_ds,
    batch_size=BATCH_SIZE,
    validation_data=val_ds,
    verbose=1,
    epochs=EPOCHS,
)
# Out:
# Epoch 1/98
# 46/46 [==============================] - 434s 812ms/step - loss: 0.8048 - accuracy: 0.7108 - val_loss: 0.3547 - val_accuracy: 0.8813
# Epoch 2/98
# 46/46 [==============================] - 26s 559ms/step - loss: 0.3729 - accuracy: 0.8834 - val_loss: 0.2133 - val_accuracy: 0.9438
# Epoch 3/98
# 46/46 [==============================] - 26s 556ms/step - loss: 0.2771 - accuracy: 0.9263 - val_loss: 0.1676 - val_accuracy: 0.9500
# Epoch 4/98
# 46/46 [==============================] - 26s 561ms/step - loss: 0.2274 - accuracy: 0.9427 - val_loss: 0.1432 - val_accuracy: 0.9625
# Epoch 5/98
# 46/46 [==============================] - 26s 565ms/step - loss: 0.2174 - accuracy: 0.9338 - val_loss: 0.1212 - val_accuracy: 0.9750
# Epoch 6/98
# 46/46 [==============================] - 25s 553ms/step - loss: 0.1844 - accuracy: 0.9523 - val_loss: 0.1223 - val_accuracy: 0.9750
# Epoch 7/98
# 46/46 [==============================] - 26s 555ms/step - loss: 0.1758 - accuracy: 0.9543 - val_loss: 0.1076 - val_accuracy: 0.9688
# Epoch 8/98
# 46/46 [==============================] - 26s 572ms/step - loss: 0.1629 - accuracy: 0.9509 - val_loss: 0.0904 - val_accuracy: 0.9812
# Epoch 9/98
# 46/46 [==============================] - 26s 561ms/step - loss: 0.1443 - accuracy: 0.9611 - val_loss: 0.0912 - val_accuracy: 0.9812
# Epoch 10/98
# 46/46 [==============================] - 26s 556ms/step - loss: 0.1371 - accuracy: 0.9563 - val_loss: 0.0871 - val_accuracy: 0.9750
# Epoch 11/98
# 46/46 [==============================] - 26s 569ms/step - loss: 0.1405 - accuracy: 0.9632 - val_loss: 0.0937 - val_accuracy: 0.9812
# Epoch 12/98
# 46/46 [==============================] - 26s 557ms/step - loss: 0.1322 - accuracy: 0.9570 - val_loss: 0.0864 - val_accuracy: 0.9750
# Epoch 13/98
# 46/46 [==============================] - 26s 561ms/step - loss: 0.1323 - accuracy: 0.9543 - val_loss: 0.0868 - val_accuracy: 0.9812
# Epoch 14/98
# 46/46 [==============================] - 31s 673ms/step - loss: 0.1236 - accuracy: 0.9625 - val_loss: 0.0856 - val_accuracy: 0.9812
# Epoch 15/98
# 46/46 [==============================] - 33s 719ms/step - loss: 0.1224 - accuracy: 0.9659 - val_loss: 0.0796 - val_accuracy: 0.9812
# Epoch 16/98
# 46/46 [==============================] - 26s 558ms/step - loss: 0.1113 - accuracy: 0.9700 - val_loss: 0.0773 - val_accuracy: 0.9812
# Epoch 17/98
# 46/46 [==============================] - 26s 556ms/step - loss: 0.1189 - accuracy: 0.9577 - val_loss: 0.0754 - val_accuracy: 0.9812
# Epoch 18/98
# 46/46 [==============================] - 26s 562ms/step - loss: 0.1127 - accuracy: 0.9632 - val_loss: 0.0737 - val_accuracy: 0.9750
# Epoch 19/98
# 46/46 [==============================] - 26s 557ms/step - loss: 0.1037 - accuracy: 0.9720 - val_loss: 0.0839 - val_accuracy: 0.9750
# Epoch 20/98
# 46/46 [==============================] - 25s 551ms/step - loss: 0.0977 - accuracy: 0.9741 - val_loss: 0.0803 - val_accuracy: 0.9812
# Epoch 21/98
# 46/46 [==============================] - 26s 568ms/step - loss: 0.1053 - accuracy: 0.9645 - val_loss: 0.0691 - val_accuracy: 0.9875
# Epoch 22/98
# 46/46 [==============================] - 26s 561ms/step - loss: 0.0979 - accuracy: 0.9686 - val_loss: 0.0751 - val_accuracy: 0.9750
# Epoch 23/98
# 46/46 [==============================] - 25s 551ms/step - loss: 0.0853 - accuracy: 0.9734 - val_loss: 0.0633 - val_accuracy: 0.9875
# Epoch 24/98
# 46/46 [==============================] - 26s 563ms/step - loss: 0.0897 - accuracy: 0.9727 - val_loss: 0.0602 - val_accuracy: 0.9812
# Epoch 25/98
# 46/46 [==============================] - 26s 557ms/step - loss: 0.0821 - accuracy: 0.9741 - val_loss: 0.0737 - val_accuracy: 0.9812
# Epoch 26/98
# 46/46 [==============================] - 25s 538ms/step - loss: 0.0850 - accuracy: 0.9741 - val_loss: 0.0583 - val_accuracy: 0.9812
# Epoch 27/98
# 46/46 [==============================] - 25s 547ms/step - loss: 0.0804 - accuracy: 0.9741 - val_loss: 0.0614 - val_accuracy: 0.9750
# Epoch 28/98
# 46/46 [==============================] - 25s 549ms/step - loss: 0.0735 - accuracy: 0.9734 - val_loss: 0.0673 - val_accuracy: 0.9812
# Epoch 29/98
# 46/46 [==============================] - 25s 546ms/step - loss: 0.0824 - accuracy: 0.9761 - val_loss: 0.0662 - val_accuracy: 0.9812
# Epoch 30/98
# 46/46 [==============================] - 25s 539ms/step - loss: 0.0807 - accuracy: 0.9700 - val_loss: 0.0513 - val_accuracy: 0.9812
# Epoch 31/98
# 46/46 [==============================] - 27s 580ms/step - loss: 0.0924 - accuracy: 0.9734 - val_loss: 0.0655 - val_accuracy: 0.9812
# Epoch 32/98
# 46/46 [==============================] - 25s 550ms/step - loss: 0.0850 - accuracy: 0.9741 - val_loss: 0.0551 - val_accuracy: 0.9812
# Epoch 33/98
# 46/46 [==============================] - 25s 548ms/step - loss: 0.0789 - accuracy: 0.9768 - val_loss: 0.0568 - val_accuracy: 0.9812
# Epoch 34/98
# 46/46 [==============================] - 26s 559ms/step - loss: 0.0687 - accuracy: 0.9864 - val_loss: 0.0533 - val_accuracy: 0.9812
# Epoch 35/98
# 46/46 [==============================] - 26s 562ms/step - loss: 0.0668 - accuracy: 0.9768 - val_loss: 0.0645 - val_accuracy: 0.9812
# Epoch 36/98
# 46/46 [==============================] - 25s 546ms/step - loss: 0.0812 - accuracy: 0.9734 - val_loss: 0.0593 - val_accuracy: 0.9812
# Epoch 37/98
# 46/46 [==============================] - 25s 553ms/step - loss: 0.0754 - accuracy: 0.9775 - val_loss: 0.0540 - val_accuracy: 0.9812
# Epoch 38/98
# 46/46 [==============================] - 25s 551ms/step - loss: 0.0596 - accuracy: 0.9809 - val_loss: 0.0476 - val_accuracy: 0.9812
# Epoch 39/98
# 46/46 [==============================] - 25s 534ms/step - loss: 0.0639 - accuracy: 0.9782 - val_loss: 0.0644 - val_accuracy: 0.9812
# Epoch 40/98
# 46/46 [==============================] - 25s 540ms/step - loss: 0.0721 - accuracy: 0.9741 - val_loss: 0.0513 - val_accuracy: 0.9812
# Epoch 41/98
# 46/46 [==============================] - 26s 551ms/step - loss: 0.0715 - accuracy: 0.9795 - val_loss: 0.0652 - val_accuracy: 0.9812
# Epoch 42/98
# 46/46 [==============================] - 25s 548ms/step - loss: 0.0685 - accuracy: 0.9782 - val_loss: 0.0631 - val_accuracy: 0.9750
# Epoch 43/98
# 46/46 [==============================] - 25s 535ms/step - loss: 0.0670 - accuracy: 0.9782 - val_loss: 0.0458 - val_accuracy: 0.9812
# Epoch 44/98
# 46/46 [==============================] - 26s 554ms/step - loss: 0.0596 - accuracy: 0.9823 - val_loss: 0.0493 - val_accuracy: 0.9812
# Epoch 45/98
# 46/46 [==============================] - 25s 548ms/step - loss: 0.0708 - accuracy: 0.9754 - val_loss: 0.0687 - val_accuracy: 0.9750
# Epoch 46/98
# 46/46 [==============================] - 25s 549ms/step - loss: 0.0587 - accuracy: 0.9836 - val_loss: 0.0584 - val_accuracy: 0.9812
# Epoch 47/98
# 46/46 [==============================] - 26s 556ms/step - loss: 0.0599 - accuracy: 0.9816 - val_loss: 0.0558 - val_accuracy: 0.9812
# Epoch 48/98
# 46/46 [==============================] - 25s 535ms/step - loss: 0.0599 - accuracy: 0.9802 - val_loss: 0.0530 - val_accuracy: 0.9812
# Epoch 49/98
# 46/46 [==============================] - 25s 548ms/step - loss: 0.0558 - accuracy: 0.9857 - val_loss: 0.0457 - val_accuracy: 0.9750
# Epoch 50/98
# 46/46 [==============================] - 26s 562ms/step - loss: 0.0537 - accuracy: 0.9829 - val_loss: 0.0388 - val_accuracy: 0.9937
# Epoch 51/98
# 46/46 [==============================] - 25s 553ms/step - loss: 0.0546 - accuracy: 0.9843 - val_loss: 0.0625 - val_accuracy: 0.9750
# Epoch 52/98
# 46/46 [==============================] - 25s 548ms/step - loss: 0.0562 - accuracy: 0.9829 - val_loss: 0.0458 - val_accuracy: 0.9812
# Epoch 53/98
# 46/46 [==============================] - 25s 544ms/step - loss: 0.0593 - accuracy: 0.9850 - val_loss: 0.0443 - val_accuracy: 0.9812
# Epoch 54/98
# 46/46 [==============================] - 25s 550ms/step - loss: 0.0572 - accuracy: 0.9864 - val_loss: 0.0518 - val_accuracy: 0.9812
# Epoch 55/98
# 46/46 [==============================] - 26s 556ms/step - loss: 0.0545 - accuracy: 0.9829 - val_loss: 0.0447 - val_accuracy: 0.9812
# Epoch 56/98
# 46/46 [==============================] - 25s 542ms/step - loss: 0.0594 - accuracy: 0.9829 - val_loss: 0.0577 - val_accuracy: 0.9812
# Epoch 57/98
# 46/46 [==============================] - 26s 554ms/step - loss: 0.0514 - accuracy: 0.9809 - val_loss: 0.0453 - val_accuracy: 0.9812
# Epoch 58/98
# 46/46 [==============================] - 25s 553ms/step - loss: 0.0613 - accuracy: 0.9816 - val_loss: 0.0504 - val_accuracy: 0.9812
# Epoch 59/98
# 46/46 [==============================] - 25s 551ms/step - loss: 0.0516 - accuracy: 0.9816 - val_loss: 0.0532 - val_accuracy: 0.9812
# Epoch 60/98
# 46/46 [==============================] - 26s 562ms/step - loss: 0.0568 - accuracy: 0.9843 - val_loss: 0.0445 - val_accuracy: 0.9875
# Epoch 61/98
# 46/46 [==============================] - 25s 545ms/step - loss: 0.0461 - accuracy: 0.9905 - val_loss: 0.0372 - val_accuracy: 0.9875
# Epoch 62/98
# 46/46 [==============================] - 25s 553ms/step - loss: 0.0444 - accuracy: 0.9857 - val_loss: 0.0402 - val_accuracy: 0.9812
# Epoch 63/98
# 46/46 [==============================] - 25s 554ms/step - loss: 0.0538 - accuracy: 0.9823 - val_loss: 0.0386 - val_accuracy: 0.9812
# Epoch 64/98
# 46/46 [==============================] - 25s 552ms/step - loss: 0.0542 - accuracy: 0.9816 - val_loss: 0.0376 - val_accuracy: 0.9875
# Epoch 65/98
# 46/46 [==============================] - 25s 550ms/step - loss: 0.0464 - accuracy: 0.9877 - val_loss: 0.0398 - val_accuracy: 0.9812
# Epoch 66/98
# 46/46 [==============================] - 26s 558ms/step - loss: 0.0406 - accuracy: 0.9891 - val_loss: 0.0537 - val_accuracy: 0.9812
# Epoch 67/98
# 46/46 [==============================] - 26s 558ms/step - loss: 0.0438 - accuracy: 0.9870 - val_loss: 0.0392 - val_accuracy: 0.9875
# Epoch 68/98
# 46/46 [==============================] - 25s 538ms/step - loss: 0.0521 - accuracy: 0.9836 - val_loss: 0.0367 - val_accuracy: 0.9937
# Epoch 69/98
# 46/46 [==============================] - 25s 550ms/step - loss: 0.0397 - accuracy: 0.9905 - val_loss: 0.0360 - val_accuracy: 0.9812
# Epoch 70/98
# 46/46 [==============================] - 26s 555ms/step - loss: 0.0470 - accuracy: 0.9857 - val_loss: 0.0348 - val_accuracy: 0.9937
# Epoch 71/98
# 46/46 [==============================] - 25s 553ms/step - loss: 0.0430 - accuracy: 0.9843 - val_loss: 0.0309 - val_accuracy: 0.9937
# Epoch 72/98
# 46/46 [==============================] - 25s 538ms/step - loss: 0.0418 - accuracy: 0.9857 - val_loss: 0.0361 - val_accuracy: 0.9812
# Epoch 73/98
# 46/46 [==============================] - 25s 552ms/step - loss: 0.0542 - accuracy: 0.9829 - val_loss: 0.0342 - val_accuracy: 0.9875
# Epoch 74/98
# 46/46 [==============================] - 25s 548ms/step - loss: 0.0386 - accuracy: 0.9870 - val_loss: 0.0364 - val_accuracy: 0.9875
# Epoch 75/98
# 46/46 [==============================] - 25s 551ms/step - loss: 0.0424 - accuracy: 0.9870 - val_loss: 0.0415 - val_accuracy: 0.9812
# Epoch 76/98
# 46/46 [==============================] - 26s 562ms/step - loss: 0.0445 - accuracy: 0.9877 - val_loss: 0.0517 - val_accuracy: 0.9812
# Epoch 77/98
# 46/46 [==============================] - 25s 552ms/step - loss: 0.0483 - accuracy: 0.9843 - val_loss: 0.0293 - val_accuracy: 0.9937
# Epoch 78/98
# 46/46 [==============================] - 25s 553ms/step - loss: 0.0505 - accuracy: 0.9843 - val_loss: 0.0327 - val_accuracy: 0.9875
# Epoch 79/98
# 46/46 [==============================] - 25s 553ms/step - loss: 0.0416 - accuracy: 0.9877 - val_loss: 0.0350 - val_accuracy: 0.9875
# Epoch 80/98
# 46/46 [==============================] - 25s 551ms/step - loss: 0.0311 - accuracy: 0.9932 - val_loss: 0.0390 - val_accuracy: 0.9875
# Epoch 81/98
# 46/46 [==============================] - 25s 549ms/step - loss: 0.0454 - accuracy: 0.9843 - val_loss: 0.0367 - val_accuracy: 0.9812
# Epoch 82/98
# 46/46 [==============================] - 26s 562ms/step - loss: 0.0443 - accuracy: 0.9816 - val_loss: 0.0351 - val_accuracy: 0.9937
# Epoch 83/98
# 46/46 [==============================] - 25s 554ms/step - loss: 0.0390 - accuracy: 0.9891 - val_loss: 0.0398 - val_accuracy: 0.9875
# Epoch 84/98
# 46/46 [==============================] - 26s 559ms/step - loss: 0.0422 - accuracy: 0.9891 - val_loss: 0.0392 - val_accuracy: 0.9812
# Epoch 85/98
# 46/46 [==============================] - 25s 548ms/step - loss: 0.0389 - accuracy: 0.9898 - val_loss: 0.0391 - val_accuracy: 0.9812
# Epoch 86/98
# 46/46 [==============================] - 26s 555ms/step - loss: 0.0440 - accuracy: 0.9877 - val_loss: 0.0342 - val_accuracy: 0.9812
# Epoch 87/98
# 46/46 [==============================] - 25s 552ms/step - loss: 0.0408 - accuracy: 0.9905 - val_loss: 0.0425 - val_accuracy: 0.9750
# Epoch 88/98
# 46/46 [==============================] - 25s 549ms/step - loss: 0.0381 - accuracy: 0.9891 - val_loss: 0.0515 - val_accuracy: 0.9750
# Epoch 89/98
# 46/46 [==============================] - 26s 566ms/step - loss: 0.0416 - accuracy: 0.9864 - val_loss: 0.0473 - val_accuracy: 0.9812
# Epoch 90/98
# 46/46 [==============================] - 26s 552ms/step - loss: 0.0384 - accuracy: 0.9898 - val_loss: 0.0474 - val_accuracy: 0.9750
# Epoch 91/98
# 46/46 [==============================] - 25s 541ms/step - loss: 0.0363 - accuracy: 0.9870 - val_loss: 0.0434 - val_accuracy: 0.9812
# Epoch 92/98
# 46/46 [==============================] - 25s 546ms/step - loss: 0.0367 - accuracy: 0.9918 - val_loss: 0.0448 - val_accuracy: 0.9812
# Epoch 93/98
# 46/46 [==============================] - 26s 560ms/step - loss: 0.0442 - accuracy: 0.9877 - val_loss: 0.0453 - val_accuracy: 0.9812
# Epoch 94/98
# 46/46 [==============================] - 25s 549ms/step - loss: 0.0424 - accuracy: 0.9898 - val_loss: 0.0407 - val_accuracy: 0.9875
# Epoch 95/98
# 46/46 [==============================] - 25s 548ms/step - loss: 0.0337 - accuracy: 0.9911 - val_loss: 0.0384 - val_accuracy: 0.9812
# Epoch 96/98
# 46/46 [==============================] - 26s 561ms/step - loss: 0.0386 - accuracy: 0.9905 - val_loss: 0.0335 - val_accuracy: 0.9875
# Epoch 97/98
# 46/46 [==============================] - 26s 556ms/step - loss: 0.0324 - accuracy: 0.9905 - val_loss: 0.0398 - val_accuracy: 0.9812
# Epoch 98/98
# 46/46 [==============================] - 25s 552ms/step - loss: 0.0415 - accuracy: 0.9857 - val_loss: 0.0428 - val_accuracy: 0.9750

# %%
scores = resnet50_model.evaluate(test_ds)
print(f"Test Accuracy: {round(scores[1],4)*100}%")
# Out:
# 7/7 [==============================] - 8s 125ms/step - loss: 0.0874 - accuracy: 0.9688
# Test Accuracy: 96.88%

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
EPOCHS = len(acc)

plt.figure(figsize=(8, 5))
plt.subplot(1, 2, 1)
plt.plot(range(EPOCHS), acc, label='Training Accuracy', color='blue')
plt.plot(range(EPOCHS), val_acc, label='Validation Accuracy', color='orange')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.grid(True)
plt.show()

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']
EPOCHS = len(loss)  # Assuming loss and val_loss have the same length
plt.figure(figsize=(8, 5))
plt.subplot(1, 2, 2)
plt.plot(range(EPOCHS), loss, label='Training Loss', color='blue')
plt.plot(range(EPOCHS), val_loss, label='Validation Loss', color='orange')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.show()

# %%
# Make predictions using the model
predictions = resnet50_model.predict(test_ds)
# Get the predicted class labels
predicted_labels = [np.argmax(prediction) for prediction in predictions]
test_labels = []
for images, labels in test_ds:
    test_labels.extend(labels.numpy())
test_labels = np.array(test_labels)
confusion = confusion_matrix(test_labels, predicted_labels)

print("Confusion Matrix:")
print(confusion)
# Out:
# 7/7 [==============================] - 1s 126ms/step
# Confusion Matrix:
# [[ 8  2  2  5  7  5]
#  [ 3 18  8  4  6  5]
#  [ 2  3 15  6  8  4]
#  [ 4  5  3 12  7  3]
#  [ 7  6  7  8 18  4]
#  [ 5  5  4  3  4  8]]

# %%
def plot_confusion_matrix(confusion_matrix, class_names):
    plt.figure(figsize=(5, 4))
    sns.heatmap(confusion_matrix, annot=True, fmt='d', cmap='Oranges', xticklabels=class_names, yticklabels=class_names)
    plt.xlabel('Predicted')
    plt.ylabel('Actual')
    plt.title('Confusion Matrix')
    plt.show()

# Call the function to display the confusion matrix
plot_confusion_matrix(confusion, class_names)

# %%
from sklearn.metrics import classification_report
test_labels = []  # True labels
predicted_labels = []  # Predicted labels

for images_batch, labels_batch in test_ds:
    batch_prediction = resnet50_model.predict(images_batch)
    predicted_labels.extend(np.argmax(batch_prediction, axis=1))
    test_labels.extend(labels_batch.numpy())
report = classification_report(test_labels, predicted_labels, target_names=class_names)
print(report)
# Out:
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 50ms/step
#                        precision    recall  f1-score   support
#
# Bacterial_leaf_blight       0.97      0.97      0.97        29
#            Brown_spot       1.00      0.89      0.94        44
#          Healthy_leaf       0.97      1.00      0.99        38
#            Leaf_Blast       0.89      1.00      0.94        34
#                 Other       1.00      1.00      1.00        50
#                Tungro       0.97      0.97      0.97        29
#
#              accuracy                           0.97       224
#             macro avg       0.97      0.97      0.97       224
#          weighted avg       0.97      0.97      0.97       224

# %%
for images_batch, labels_batch in test_ds.take(1):

    first_image = images_batch[0].numpy().astype('uint8')
    first_label = labels_batch[0].numpy()

    print("first image to predict")
    plt.imshow(first_image)
    print("actual label:",class_names[first_label])

    batch_prediction = resnet50_model.predict(images_batch)
    print("predicted label:",class_names[np.argmax(batch_prediction[0])])
# Out:
# first image to predict
# actual label: Healthy_leaf
# 1/1 [==============================] - 0s 36ms/step
# predicted label: Healthy_leaf
